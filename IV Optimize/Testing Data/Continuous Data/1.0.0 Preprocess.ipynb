# %%
import pandas as pd
# Set max columns to display
pd.set_option('display.max_columns', None)
import numpy as np
from sklearn import preprocessing as pre
import matplotlib.pyplot as plt
# Out:
# C:\Users\austinsh\AppData\Local\Temp\ipykernel_15752\753047149.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Importing CSV files
#
# Switching to a gitHub source for CSV imports
#
#
# url = 'paste_the_raw_github_url_here'
#
# df = pd.read_csv(url)

# %%
########################################################################################################################
##############################                                                            ##############################
##############################                           IMPORT DATA                      ##############################      
##############################                                                            ##############################
########################################################################################################################
# ABB1_split_1 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB1_split_1.csv')
# ABB1_split_2 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB1_split_2.csv')
# ABB1_1 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB1_1.csv')
# ABB1_2 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB1_2.csv')
# ABB1_4 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB1_4.csv')
# ABB1_6 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB1_6.csv')
# ABB2_split_1 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB2_split_1.csv')
# ABB2_split_2 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB2_split_2.csv')
# ABB2_1 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB2_1.csv')
# ABB2_2 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB2_2.csv')
# ABB2_4 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB2_4.csv')
# ABB2_5 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB2_5.csv')
# ABB3 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB3.csv')
# ABB3_1 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB3_1.csv')
# ABB3_2 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB3_2.csv')
# ABB4 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB4.csv')
# ABB51 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB51.csv')
# ABB55 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB55.csv')
# ABBp = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABBp.csv')

# AlFlow1 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/AlFlow1.csv')

# DeltaV = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/DeltaV.csv')
# DeltaV1 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/DeltaV1.csv')
# DeltaV2 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/DeltaV2.csv')
# DeltaV4 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/DeltaV4.csv')
# DeltaV5 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/DeltaV5.csv')

# DeltaVp = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/DeltaVp.csv')

# DeltaVR_split_1 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/DeltaVR_split_1.csv')
# DeltaVR_split_2 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/DeltaVR_split_2.csv')


# FC55555_ABB = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/FC55555_ABB.csv')
# FC55555_DeltaV = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/FC55555_DeltaV.csv')

# LIMS = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/LIM%20-%20554%20-%20Interpolated.csv')
# LIMS1 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/LIMS%20Actuals/LIMS1.csv')
# LIMS2 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/LIMS%20Actuals/LIMS2.csv')
# LIMS3 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/LIMS%20Actuals/LIMS3.csv')
# LIMS4 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/LIMS%20Actuals/LIMS4.csv')

# rC4f_DeltaV = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/rC4f_DeltaV.csv')






# ##############   Depricated Files due to Duplicats   ############# #

# ABB1_3, #ABB1_5, #ABB5, #ABB11, ABB2_3 ,#ABB22, ABB33, ABB44, ABB56,  rC4f_ABB, LIMS1
# ABB1_3 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB1_3.csv')
# ABB1_5 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB1_5.csv')
# ABB2_3 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB2_3.csv')
# ABB5 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB5.csv')
# ABB11 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB11.csv')
# ABB22 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB22.csv')
# ABB33 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB33.csv')
# ABB44 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB44.csv')
# ABB56 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/ABB56.csv')
# DeltaV3 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/DeltaV - XV90911 - HS52551.csv')
# LIMS1 = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/LIMS1.csv')
# rC4f_ABB = pd.read_csv('https://raw.githubusercontent.com/saust1/Project-OptiC4/main/CSV/PVs/rC4f_ABB.csv')

# %% [markdown]
# Below is the code for on-prem data import

# %%
# ########################################################################################################################
# ##############################                                                            ##############################
# ##############################                           IMPORT DATA                      ##############################      
# ##############################                                                            ##############################
# ########################################################################################################################
ABB1_split_1 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB1_split_1.csv")
ABB1_split_2 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB1_split_2.csv")
ABB1_1 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB1_1.csv")
ABB1_2 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB1_2.csv")
ABB1_4 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB1_4.csv")
ABB1_6 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB1_6.csv")
ABB2_split_1 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB2_split_1.csv")
ABB2_split_2 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB2_split_2.csv")
ABB2_1 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB2_1.csv")
ABB2_2 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB2_2.csv")
ABB2_4 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB2_4.csv")
ABB2_5 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB2_5.csv")
ABB3 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB3.csv")
ABB3_1 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB3_1.csv")
ABB3_2 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB3_2.csv")
ABB4 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB4.csv")
ABB51 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB51.csv")
ABB55 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB55.csv")
ABBp = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABBp.csv")

AlFlow1 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\AlFlow1.csv")

DeltaV = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\DeltaV.csv")
DeltaV1 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\DeltaV1.csv")
DeltaV2 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\DeltaV2.csv")
DeltaV4 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\DeltaV4.csv")
DeltaV5 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\DeltaV5.csv")

DeltaVp = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\DeltaVp.csv")

DeltaVR_split_1 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\DeltaVR_split_1.csv")
DeltaVR_split_2 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\DeltaVR_split_2.csv")


FC55555_ABB = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\FC55555_ABB.csv")
FC55555_DeltaV = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\FC55555_DeltaV.csv")

LIMS = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\LIM - 554 - Interpolated.csv")
LIMS1 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\LIMS Actuals\LIMS1.csv")
LIMS2 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\LIMS Actuals\LIMS2.csv")
LIMS3 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\LIMS Actuals\LIMS3.csv")
LIMS4 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\LIMS Actuals\LIMS4.csv")


rC4f_DeltaV = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\rC4f_DeltaV.csv")

# ABB1_3, #ABB1_5, #ABB5, #ABB11, ABB2_3 ,#ABB22, ABB33, ABB44, ABB56,  rC4f_ABB, LIMS1
# ABB1_3 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB1_3.csv")
# ABB1_5 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB1_5.csv")
# ABB2_3 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB2_3.csv")
# ABB5 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB5.csv")
# ABB11 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB11.csv")
# ABB22 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB22.csv")
# ABB33 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB33.csv")
# ABB44 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB44.csv")
# ABB56 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\ABB56.csv")
# DeltaV3 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\DeltaV - XV90911 - HS52551.csv")
# LIMS1 = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\LIMS1.csv")
# rC4f_ABB = pd.read_csv(r"C:\Users\austinsh\Project-OptiC4\II Data\1 Collection\CSV\PVs\rC4f_ABB.csv")

# %%
# Assuming your dataframes are stored in a list like this:
dataframes = [ABB1_split_1, ABB1_split_2, ABB1_1, ABB1_2, ABB1_4, ABB1_6, ABB2_split_1, ABB2_split_2, ABB2_1,
                ABB2_4, ABB2_5, ABB3, ABB3_1, ABB3_2, ABB4, ABB51,
                ABB55, ABBp, AlFlow1, DeltaV, DeltaV1, DeltaV2, DeltaV4, 
                DeltaV5, DeltaVp, DeltaVR_split_1, DeltaVR_split_2, LIMS, rC4f_DeltaV, ABB2_2
                ]

duplicates = []

# Compare each dataframe with every other dataframe
for i, df1 in enumerate(dataframes):
    for j, df2 in enumerate(dataframes):
        if i != j and df1.equals(df2):
            duplicates.append((i, j))

# Report the results
if duplicates:
    print("Duplicate dataframes found:")
    for i, j in duplicates:
        print(f"Dataframe at index {i} is the same as dataframe at index {j}.")
else:
    print("No duplicate dataframes found.")
# Out:
# No duplicate dataframes found.

# %%
# Concatenate (union) the dataframes
df = pd.concat([ABB1_split_1, ABB1_split_2, ABB1_1, ABB1_2, ABB1_4, ABB1_6, 
                ABB2_split_1, ABB2_split_2, ABB2_1, ABB2_2, ABB2_4, ABB2_5,
                ABB3, ABB3_1, ABB3_2, ABB4, 
                ABB51, ABB55, 
                ABBp, AlFlow1, 
                DeltaV, DeltaV1, DeltaV2, DeltaV4, DeltaV5, DeltaVp, DeltaVR_split_1, DeltaVR_split_2,
                LIMS, LIMS1, LIMS2, LIMS3, LIMS4,
                rC4f_DeltaV], ignore_index=True)

print(df.head())
# Out:
#             Date       ID    Value
# 0  5/9/2012 0:00  TI40050  71.6833
# 1  5/9/2012 1:00  TI40050  71.5945
# 2  5/9/2012 2:00  TI40050  71.6942
# 3  5/9/2012 3:00  TI40050  71.9178
# 4  5/9/2012 4:00  TI40050  71.7137

# %%
# Assuming df is your DataFrame and 'ID' is the column
distinct_ids = df['ID'].unique()

print("Distinct IDs:")
print(distinct_ids)
# Out:
# Distinct IDs:
# ['TI40050' 'FC52018' 'FC55003' 'FC55009' 'FC55102' 'FC55152' 'FC55552'
#  'FC55569' 'FC55576' 'FFC55553' 'FFC55555' 'FYC55553' 'LC52572' 'LC55553'
#  'LC55555' 'LC55557' 'LC55568' 'LC90366' 'LC90368' 'TC52015' 'TC55552'
#  'TC55553' 'TC55555' 'TC55566' 'TI55017' 'TI55013' 'TI55021' 'TI55023'
#  'PI55004' 'PI55560' 'PI55020' 'AYC55580' 'DI55102' 'TI55014' 'TI55015'
#  'TI55016' 'DI55152' 'DI55580' 'FC55555' 'TI52014' 'II52554' 'VI52558B'
#  'FC42428' 'FC42428_ABB' 'FC03043213' 'HS52551' 'XV90911' 'DI52018'
#  'FI55580' 'TI55565A' 'AS74550-4EthanolPP' 'AS74550-4ButanolPP'
#  'AS74550-4HexanolPP' 'AS74550-4OctanolPP' 'AS74550-4DecanolPP'
#  'AS73425-3%Al' 'AS74550-25%C2OH' 'AS74550-25%nC6OH' 'AS74550-25%nC4OH'
#  'AS74550-25%H2O' 'AS74550-10%M-Value' 'AS74550-1%Al2O3' 'AS74550-5%pH'
#  'AS74550-5ppmNa2O' 'AS74550-5%NH4OH']

# %% [markdown]
# IDs to drop - if needed.

# %%
ids_to_drop = [

# #     # Potential Filtering or Blocking data
#         # Atomizer Data
#    "FC52018", "TI52014", "VI52558B", "II52554", 'DI52018',
#         # Stripper pressures
#    "PI55560", "PI55004", "PI55020", "TI40050", 
#         # Categorical valve postions
#    "HS90911", "HS52551", 'XV90911',
    
#     # Not Targeting with the Model
#    "AS74550-4EthanolPP", "AS74550-4HexanolPP", "AS74550-4OctanolPP"
 ]

# # Drop rows with specified IDs
# df = df[~df['ID'].isin(ids_to_drop)]

# # df.columns

# %% [markdown]
# # Final Dataset Cleaning
#
# ## These are the Butanol required Features:
#
# ### Muted for Decanol Development:
# Perhaps consider not returning here to run the page. Instead create a function from this page and call it when needed to re-"preprocess." The re-Preprocess ensure minimal data loss due to drops from other features that are not part of the final feature selection.

# %%
# ids_to_keep = ['AS73425-3%Al', 'AS74550-4ButanolPP',
#                     'FC55569', 'DI55152', 'TC55552',
#                     'FC55003', 'LC55555', 'FFC55553',
#                     'FFC55555', 'TI55021',
#                     'PI55004', 'FC55552',
                                 
#                'AS74550-25%C2OH', 'AS74550-25%nC4OH',
#                'AS74550-25%H2O', 'AS74550-10%M-Value', 
#                'AS74550-5%pH', 'AS74550-5%NH4OH'
               # ]
   # 'AS74550-4DecanolPP': 'Decanol',, 'AS74550-5ppmNa2O', 'AS74550-25%nC6OH' 'TC55555',

# Keep only rows with specified IDs
# df = df[df['ID'].isin(ids_to_keep)]

# %%
print(df.shape[0])

# 3555736 - Before change to include all features (assuming its the butanol only req attributes)
# 11313917 - After including all features
# Out:
# 11313917

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y %H:%M', errors='coerce')

print(df.head())
# Out:
#                  Date       ID    Value
# 0 2012-05-09 00:00:00  TI40050  71.6833
# 1 2012-05-09 01:00:00  TI40050  71.5945
# 2 2012-05-09 02:00:00  TI40050  71.6942
# 3 2012-05-09 03:00:00  TI40050  71.9178
# 4 2012-05-09 04:00:00  TI40050  71.7137

# %%
#Analysis of the larger yeallow area found an error in the timestamp conversiona
## Some timestamps were converted to "35" minutes instead of "25" minutes

#This will be corrected (yyyy-mm-dd hh:35:ss --> yyyy-mm-dd hh:00:ss)
# Assuming you have reset the index and kept the timestamp as a separate column named "Date"
#df['Date'] = df['Date'].apply(lambda dt: dt.replace(minute=0, second=0))

# Count rows where minute or second is not 0 before transformation
corrections_before = df[df['Date'].apply(lambda dt: dt.minute != 0 or dt.second != 0)].shape[0]

# Apply transformation
df['Date'] = df['Date'].apply(lambda dt: dt.replace(minute=0, second=0))

# The number of corrections is the count of rows where minute or second was not 0
print(f"{corrections_before} corrections were made.")
# Out:
# 200208 corrections were made.

# %%
#200208 - before duplicate dfs removed

# The data needs to be pivoted to:

# Unique row headers by 'Date'
# Unique column headers by 'ID'
# Values by 'Data'

#Previous attempt to pivot indicated Duplicates realtive to Date/ID
## These duplicates prevented the pivot

#First we must remove the duplicates then Pivot

# %%
#Identify the duplicates by all columns (Exact duplicates)

duplicate_counts = df.groupby(['Date', 'ID', 'Value']).size().reset_index(name='count')
duplicates_with_counts = duplicate_counts[duplicate_counts['count'] > 1]
print(duplicates_with_counts)

#165 10/24/23
#1378574 ALL DATA  ['Date', 'ID']
#1322098 ALL DATA  ['Date', 'ID', 'Data']
# Out:
#                        Date        ID         Value  count
# 141694  2011-11-06 01:00:00   FC55576      1.828960      2
# 257107  2012-05-09 00:00:00   FC55003   2062.630000      3
# 257108  2012-05-09 00:00:00   FC55009    473.326000      4
# 257109  2012-05-09 00:00:00   FC55102   2073.460000      3
# 257110  2012-05-09 00:00:00   FC55152   -864.702000      4
# ...                     ...       ...           ...    ...
# 6324575 2023-08-31 22:00:00   FC55569   6226.910000      2
# 6324576 2023-08-31 22:00:00   FC55576    484.534000      2
# 6324578 2023-08-31 22:00:00  FFC55555      0.779807      2
# 6324579 2023-08-31 22:00:00  FYC55553  30291.300000      2
# 6324592 2023-08-31 22:00:00   TC55552    159.604000      2
#
# [2796021 rows x 4 columns]

# %%
df_clean = df.drop_duplicates(subset=['Date', 'ID', 'Value'])

# %%
########## Actual Duplicates to CSV file ##########

# # Find and print duplicates based on 'Date' and 'ID' columns
# duplicates = df[df.duplicated(subset=['Date', 'ID'], keep=False)]
# print(duplicates)

# duplicates.to_csv('duplicates.csv', index=False)

# %%
# Remove the Duplicates

#Analysis of duplicates based on ID and Date are not standard across Data for all 332 occurence
# Averaging would not be consitent across all duplicate because of the wide spread between various duplicate
#Therefore REMOVE all 332 as invalid instead of introducing bias arbitraiarly 

# Drop duplicates based on 'Date' and 'ID' columns from df_clean
print(df_clean.shape[0])
# Out:
# 6419496

# %%
#Identify the duplicates

duplicate_counts = df_clean.groupby(['Date', 'ID']).size().reset_index(name='count')
duplicates_with_counts = duplicate_counts[duplicate_counts['count'] > 1]
print(duplicates_with_counts)
# Out:
#                        Date        ID  count
# 141674  2011-11-06 01:00:00  AYC55580      2
# 141675  2011-11-06 01:00:00   DI55102      2
# 141676  2011-11-06 01:00:00   DI55152      2
# 141677  2011-11-06 01:00:00   DI55580      2
# 141678  2011-11-06 01:00:00   FC55003      2
# ...                     ...       ...    ...
# 5957020 2023-07-30 22:00:00   LC52572      2
# 5957030 2023-07-30 22:00:00   TC52015      2
# 5957066 2023-07-30 23:00:00   FC52018      2
# 5957081 2023-07-30 23:00:00   LC52572      2
# 5957091 2023-07-30 23:00:00   TC52015      2
#
# [329692 rows x 3 columns]

# %%
# Assuming df_clean is your dataframe
df_clean = df_clean.drop_duplicates(subset=['Date', 'ID'], keep='first')

# %%
print(df_clean.shape[0])
# Out:
# 5996141

# %%
#Pivot the data
df_pivot = df_clean.pivot(index='Date', columns='ID', values='Value')

# Reset the index and keep the timestamp as a separate column named "Date"
df_pivot = df_pivot.reset_index()

df_pivot.head()
# Out:
# ID                Date  AS73425-3%Al  AS74550-1%Al2O3  AS74550-10%M-Value  \
# 0                  NaT           NaN              NaN                 NaN
# 1  2011-03-24 00:00:00           NaN              NaN                 NaN
# 2  2011-03-24 01:00:00           NaN              NaN                 NaN
# 3  2011-03-24 02:00:00           NaN              NaN                 NaN
# 4  2011-03-24 03:00:00           NaN              NaN                 NaN
#
# ID  AS74550-25%C2OH  AS74550-25%H2O  AS74550-25%nC4OH  AS74550-25%nC6OH  \
# 0               NaN             NaN               NaN               NaN
# 1               NaN             NaN               NaN               NaN
# 2               NaN             NaN               NaN               NaN
# 3               NaN             NaN               NaN               NaN
# 4               NaN             NaN               NaN               NaN
#
# ID  AS74550-4ButanolPP  AS74550-4DecanolPP  AS74550-4EthanolPP  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
# ID  AS74550-4HexanolPP  AS74550-4OctanolPP  AS74550-5%NH4OH  AS74550-5%pH  \
# 0                  NaN                 NaN              NaN           NaN
# 1                  NaN                 NaN              NaN           NaN
# 2                  NaN                 NaN              NaN           NaN
# 3                  NaN                 NaN              NaN           NaN
# 4                  NaN                 NaN              NaN           NaN
#
# ID  AS74550-5ppmNa2O  AYC55580  DI52018  DI55102   DI55152   DI55580  \
# 0                NaN       NaN      NaN      NaN       NaN       NaN
# 1                NaN   1.80349      NaN  1.02539  0.942829  0.858988
# 2                NaN   1.84621      NaN  1.02493  0.942729  0.859091
# 3                NaN   2.80405      NaN  1.02639  0.942813  0.859834
# 4                NaN   3.35586      NaN  1.02764  0.942813  0.864065
#
# ID  FC03043213  FC42428  FC42428_ABB  FC52018  FC55003  FC55009       FC55102  \
# 0          NaN      NaN      18249.1      NaN      NaN      NaN           NaN
# 1          NaN      NaN          NaN      NaN      0.0  453.643  8.660000e-10
# 2          NaN      NaN          NaN      NaN      0.0  449.570  2.070000e-08
# 3          NaN      NaN          NaN      NaN      0.0  448.227  1.000000e-14
# 4          NaN      NaN          NaN      NaN      0.0  449.831  5.656280e-03
#
# ID  FC55152  FC55552  FC55555  FC55569  FC55576  FFC55553  FFC55555  FI55580  \
# 0       NaN      NaN -70.2375      NaN      NaN       NaN       NaN      NaN
# 1  -875.000      0.0      NaN      0.0      0.0   22.5687       NaN      NaN
# 2  -875.000      0.0      NaN      0.0      0.0   22.4626       NaN      NaN
# 3  -873.400      0.0      NaN      0.0      0.0   22.4968       NaN      NaN
# 4  -855.095      0.0      NaN      0.0      0.0   22.3868       NaN      NaN
#
# ID  FYC55553  HS52551  II52554  LC52572  LC55553  LC55555  LC55557   LC55568  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 1    451.201      NaN      NaN      NaN      0.0      0.0      0.0 -0.548902
# 2    450.466      NaN      NaN      NaN      0.0      0.0      0.0 -0.562500
# 3    450.532      NaN      NaN      NaN      0.0      0.0      0.0 -0.562500
# 4    447.889      NaN      NaN      NaN      0.0      0.0      0.0 -0.562500
#
# ID  LC90366  LC90368  PI55004  PI55020  PI55560  TC52015  TC55552  TC55553  \
# 0       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1       NaN      NaN      NaN      NaN      NaN      NaN  98.6649  98.7422
# 2       NaN      NaN      NaN      NaN      NaN      NaN  98.6875  98.7422
# 3       NaN      NaN      NaN      NaN      NaN      NaN  98.6723  98.7422
# 4       NaN      NaN      NaN      NaN      NaN      NaN  98.6875  98.7422
#
# ID  TC55555  TC55566  TI40050  TI52014  TI55013  TI55014  TI55015  TI55016  \
# 0       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1   98.6875      NaN      NaN      NaN  143.090  142.726  141.583  141.206
# 2   98.7225      NaN      NaN      NaN  144.502  144.267  143.485  143.292
# 3   98.7500      NaN      NaN      NaN  144.375  144.818  143.703  143.857
# 4   98.6875      NaN      NaN      NaN  142.677  142.450  145.050  145.468
#
# ID  TI55017  TI55021  TI55023  TI55565A  VI52558B  XV90911
# 0       NaN      NaN      NaN       NaN       NaN      NaN
# 1   140.479  71.1300      NaN       NaN       NaN      NaN
# 2   142.366  70.5527      NaN       NaN       NaN      NaN
# 3   141.686  70.0957      NaN       NaN       NaN      NaN
# 4   148.870  69.9630      NaN       NaN       NaN      NaN

# %%
num_columns = df_pivot.shape[1]
print("Number of features:", num_columns)
# Out:
# Number of features: 66

# %%
# Sample DataFrame

# Rename the columns
column_rename_dict = {
    'AS73425-3%Al': '425_pct_Al',
    'AS74550-4ButanolPP' : 'Butanol',
    'AS74550-4DecanolPP': 'Decanol',
    'AS74550-4EthanolPP': 'Ethanol',
    'AS74550-4HexanolPP': 'Hexanol',
    'AS74550-4OctanolPP': 'Octanol',
    'AS74550-25%C2OH': 'C4_pct_Eth',
    'AS74550-25%nC6OH': 'C4_pct_Hex',
    'AS74550-25%nC4OH': 'C4_pct_But',
    'AS74550-25%H2O': 'C4_pct_H2O',
    'AS74550-10%M-Value': 'M_Value',
    'AS74550-1%Al2O3': 'Al2O3',
    'AS74550-5%pH': 'HydWtr_pH',
    'AS74550-5ppmNa2O' : 'HydWtr_Na2O',
    'AS74550-5%NH4OH': 'HydWtr_pct_Ammonia'
}

df_pivot = df_pivot.rename(columns=column_rename_dict)

df_pivot
# Out:
# ID                    Date  425_pct_Al  Al2O3  M_Value  C4_pct_Eth  \
# 0                      NaT         NaN    NaN      NaN         NaN
# 1      2011-03-24 00:00:00         NaN    NaN      NaN         NaN
# 2      2011-03-24 01:00:00         NaN    NaN      NaN         NaN
# 3      2011-03-24 02:00:00         NaN    NaN      NaN         NaN
# 4      2011-03-24 03:00:00         NaN    NaN      NaN         NaN
# ...                    ...         ...    ...      ...         ...
# 109040 2023-08-31 19:00:00     6.32960    NaN  3.55641     1.73850
# 109041 2023-08-31 20:00:00     6.32490    NaN  3.55531     1.73862
# 109042 2023-08-31 21:00:00     6.32021    NaN  3.55420     1.73875
# 109043 2023-08-31 22:00:00     6.31551    NaN  3.55310     1.73888
# 109044 2023-08-31 23:00:00     6.31082    NaN  3.55200     1.73900
#
# ID      C4_pct_H2O  C4_pct_But  C4_pct_Hex  Butanol  Decanol  Ethanol  \
# 0              NaN         NaN         NaN      NaN      NaN      NaN
# 1              NaN         NaN         NaN      NaN      NaN      NaN
# 2              NaN         NaN         NaN      NaN      NaN      NaN
# 3              NaN         NaN         NaN      NaN      NaN      NaN
# 4              NaN         NaN         NaN      NaN      NaN      NaN
# ...            ...         ...         ...      ...      ...      ...
# 109040     18.1064         NaN    0.519485  2.54333  3.30667  3.69333
# 109041     18.1091         NaN    0.519932  2.58667  3.54333  3.88167
# 109042     18.1118         NaN    0.520379  2.63000  3.78000  4.07000
# 109043     18.1145         NaN    0.520826  2.63500  3.85667  4.08000
# 109044     18.1172         NaN    0.521273  2.64000  3.93333  4.09000
#
# ID      Hexanol  Octanol  HydWtr_pct_Ammonia  HydWtr_pH  HydWtr_Na2O  \
# 0           NaN      NaN                 NaN        NaN          NaN
# 1           NaN      NaN                 NaN        NaN          NaN
# 2           NaN      NaN                 NaN        NaN          NaN
# 3           NaN      NaN                 NaN        NaN          NaN
# 4           NaN      NaN                 NaN        NaN          NaN
# ...         ...      ...                 ...        ...          ...
# 109040  2.07667  2.84333            0.923854        NaN      2.20398
# 109041  2.13333  2.97167            0.922469        NaN      2.20735
# 109042  2.19000  3.10000            0.921083        NaN      2.21072
# 109043  2.20833  3.14500            0.919698        NaN      2.21409
# 109044  2.22667  3.19000            0.918313        NaN      2.21746
#
# ID      AYC55580  DI52018  DI55102   DI55152   DI55580  FC03043213  FC42428  \
# 0            NaN      NaN      NaN       NaN       NaN         NaN      NaN
# 1        1.80349      NaN  1.02539  0.942829  0.858988         NaN      NaN
# 2        1.84621      NaN  1.02493  0.942729  0.859091         NaN      NaN
# 3        2.80405      NaN  1.02639  0.942813  0.859834         NaN      NaN
# 4        3.35586      NaN  1.02764  0.942813  0.864065         NaN      NaN
# ...          ...      ...      ...       ...       ...         ...      ...
# 109040       NaN      NaN      NaN       NaN       NaN         NaN      NaN
# 109041       NaN      NaN      NaN       NaN       NaN         NaN      NaN
# 109042       NaN      NaN      NaN       NaN       NaN         NaN      NaN
# 109043       NaN      NaN      NaN       NaN       NaN         NaN      NaN
# 109044       NaN      NaN      NaN       NaN       NaN         NaN      NaN
#
# ID      FC42428_ABB  FC52018  FC55003  FC55009       FC55102    FC55152  \
# 0           18249.1      NaN      NaN      NaN           NaN        NaN
# 1               NaN      NaN     0.00  453.643  8.660000e-10   -875.000
# 2               NaN      NaN     0.00  449.570  2.070000e-08   -875.000
# 3               NaN      NaN     0.00  448.227  1.000000e-14   -873.400
# 4               NaN      NaN     0.00  449.831  5.656280e-03   -855.095
# ...             ...      ...      ...      ...           ...        ...
# 109040          NaN  32534.0  5048.33  605.447  3.757880e+04  39122.900
# 109041          NaN  33412.5  5135.09  625.349  3.744670e+04  37847.800
# 109042          NaN  33991.3  5273.17  614.058  3.756230e+04  38861.500
# 109043          NaN  33883.4  5315.33  618.021  3.744190e+04  36791.200
# 109044          NaN      NaN      NaN  689.568           NaN  37026.300
#
# ID      FC55552     FC55555  FC55569  FC55576   FFC55553  FFC55555  FI55580  \
# 0           NaN    -70.2375      NaN      NaN        NaN       NaN      NaN
# 1           0.0         NaN     0.00    0.000  22.568700       NaN      NaN
# 2           0.0         NaN     0.00    0.000  22.462600       NaN      NaN
# 3           0.0         NaN     0.00    0.000  22.496800       NaN      NaN
# 4           0.0         NaN     0.00    0.000  22.386800       NaN      NaN
# ...         ...         ...      ...      ...        ...       ...      ...
# 109040  33986.9  26506.5000  6226.74  497.974   0.888830  0.779393      NaN
# 109041  34018.0  26564.3000  6219.08  489.324   0.891949  0.781521      NaN
# 109042  34064.9  26544.1000  6171.00  486.476   0.891380  0.778299      NaN
# 109043  34045.1  26492.4000  6226.91  484.534   0.891981  0.779807      NaN
# 109044  33948.5  26558.7000  6215.25  479.258        NaN  0.779985      NaN
#
# ID       FYC55553  HS52551  II52554  LC52572  LC55553  LC55555  LC55557  \
# 0             NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1         451.201      NaN      NaN      NaN   0.0000   0.0000   0.0000
# 2         450.466      NaN      NaN      NaN   0.0000   0.0000   0.0000
# 3         450.532      NaN      NaN      NaN   0.0000   0.0000   0.0000
# 4         447.889      NaN      NaN      NaN   0.0000   0.0000   0.0000
# ...           ...      ...      ...      ...      ...      ...      ...
# 109040  30258.000      0.0      NaN  66.0626  64.5923  77.3944  77.7261
# 109041  30260.800      0.0      NaN  66.0063  64.3542  77.6482  76.9126
# 109042  30440.700      0.0      NaN  65.9818  64.8995  76.8171  76.4653
# 109043  30291.300      0.0      NaN  65.8986  64.4346  77.1744  76.3550
# 109044  30264.100      NaN      NaN      NaN      NaN      NaN      NaN
#
# ID        LC55568  LC90366  LC90368  PI55004   PI55020  PI55560  TC52015  \
# 0             NaN      NaN      NaN      NaN       NaN      NaN      NaN
# 1       -0.548902      NaN      NaN      NaN       NaN      NaN      NaN
# 2       -0.562500      NaN      NaN      NaN       NaN      NaN      NaN
# 3       -0.562500      NaN      NaN      NaN       NaN      NaN      NaN
# 4       -0.562500      NaN      NaN      NaN       NaN      NaN      NaN
# ...           ...      ...      ...      ...       ...      ...      ...
# 109040  39.843300  62.3726  67.0332  3.60928 -0.376287  2.02470  99.9242
# 109041  40.359300  61.7921  66.4270  3.41220 -0.568589  1.80544  96.3565
# 109042  40.247100  61.1921  65.8369  3.31190 -0.593363  1.73272  93.6134
# 109043  39.731300  60.6121  65.2480  3.37153  0.018798  1.76306  91.0423
# 109044        NaN      NaN      NaN  3.34497  0.251094  1.82561      NaN
#
# ID       TC55552   TC55553   TC55555  TC55566  TI40050  TI52014  TI55013  \
# 0            NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 1        98.6649   98.7422   98.6875      NaN      NaN      NaN  143.090
# 2        98.6875   98.7422   98.7225      NaN      NaN      NaN  144.502
# 3        98.6723   98.7422   98.7500      NaN      NaN      NaN  144.375
# 4        98.6875   98.7422   98.6875      NaN      NaN      NaN  142.677
# ...          ...       ...       ...      ...      ...      ...      ...
# 109040  159.7830  193.6240  180.0190  199.770  96.4326      NaN  209.217
# 109041  159.7250  191.8990  179.8170  200.164  94.5965      NaN  209.571
# 109042  159.4370  192.4350  179.9180  200.028  91.9880      NaN  209.099
# 109043  159.6040  194.3870  179.8670  199.995  90.0690      NaN  209.383
# 109044  159.5480       NaN       NaN      NaN      NaN      NaN  208.422
#
# ID      TI55014  TI55015  TI55016  TI55017   TI55021  TI55023  TI55565A  \
# 0           NaN      NaN      NaN      NaN       NaN      NaN       NaN
# 1       142.726  141.583  141.206  140.479   71.1300      NaN       NaN
# 2       144.267  143.485  143.292  142.366   70.5527      NaN       NaN
# 3       144.818  143.703  143.857  141.686   70.0957      NaN       NaN
# 4       142.450  145.050  145.468  148.870   69.9630      NaN       NaN
# ...         ...      ...      ...      ...       ...      ...       ...
# 109040      NaN      NaN      NaN  186.304  225.5510  225.215       NaN
# 109041      NaN      NaN      NaN  186.954  225.8760  224.725       NaN
# 109042      NaN      NaN      NaN  186.513  225.4130  224.349       NaN
# 109043      NaN      NaN      NaN  186.783  225.3410  224.598       NaN
# 109044      NaN      NaN      NaN  185.932  225.4400  224.481       NaN
#
# ID      VI52558B  XV90911
# 0            NaN      NaN
# 1            NaN      NaN
# 2            NaN      NaN
# 3            NaN      NaN
# 4            NaN      NaN
# ...          ...      ...
# 109040       NaN      0.0
# 109041       NaN      0.0
# 109042       NaN      0.0
# 109043       NaN      0.0
# 109044       NaN      NaN
#
# [109045 rows x 66 columns]

# %%
df_pivot.columns
# Out:
# Index(['Date', '425_pct_Al', 'Al2O3', 'M_Value', 'C4_pct_Eth', 'C4_pct_H2O',
#        'C4_pct_But', 'C4_pct_Hex', 'Butanol', 'Decanol', 'Ethanol', 'Hexanol',
#        'Octanol', 'HydWtr_pct_Ammonia', 'HydWtr_pH', 'HydWtr_Na2O', 'AYC55580',
#        'DI52018', 'DI55102', 'DI55152', 'DI55580', 'FC03043213', 'FC42428',
#        'FC42428_ABB', 'FC52018', 'FC55003', 'FC55009', 'FC55102', 'FC55152',
#        'FC55552', 'FC55555', 'FC55569', 'FC55576', 'FFC55553', 'FFC55555',
#        'FI55580', 'FYC55553', 'HS52551', 'II52554', 'LC52572', 'LC55553',
#        'LC55555', 'LC55557', 'LC55568', 'LC90366', 'LC90368', 'PI55004',
#        'PI55020', 'PI55560', 'TC52015', 'TC55552', 'TC55553', 'TC55555',
#        'TC55566', 'TI40050', 'TI52014', 'TI55013', 'TI55014', 'TI55015',
#        'TI55016', 'TI55017', 'TI55021', 'TI55023', 'TI55565A', 'VI52558B',
#        'XV90911'],
#       dtype='object', name='ID')

# %%
ids_to_keep = ['Date',
               '425_pct_Al',
               'M_Value', 
               'Al2O3',
               'C4_pct_Eth',
               'C4_pct_H2O',
               'HydWtr_pct_Ammonia',
               'C4_pct_Hex',
               'HydWtr_Na2O',
               'Butanol',
               'Decanol',
               'DI55102',
               'DI55152',
               'DI55580',
               'FC55003',
               'FC55009',
               'FC55552',
               'FC55569',
               'FC55576',
               'FFC55553',
               'FFC55555',
               'LC55557',
               'LC90366',
               'LC90368',
               'PI55020',
               'TC55552',
               'TI55021'
               ]
   # 'AS74550-4DecanolPP': 'Decanol',, 'AS74550-5ppmNa2O', 'AS74550-25%nC6OH' 'TC55555',

# Keep only rows with specified IDs
df_pivot = df_pivot[ids_to_keep]

# %%
# To Address the NaNs .....................................................

# %%
# Count NaNs in each row
nan_counts_per_row = df_pivot.isnull().sum(axis=1)

# Frequency distribution of NaN counts
frequency_distribution = nan_counts_per_row.value_counts().sort_index()

print(frequency_distribution)
# Out:
# 0     92553
# 1      5214
# 2       601
# 3        21
# 4       767
# 9         1
# 14     9887
# 27        1
# Name: count, dtype: int64

# %%
# Count of rows where all values are NaN
all_nan_rows_count = df_pivot.isnull().all(axis=1).sum()

# Total number of rows in pivoted_df
total_rows = len(df_pivot)

# Percentage of rows that are completely NaN
all_nan_percentage = (all_nan_rows_count / total_rows) * 100

print(f"Number of rows with NaN for every column: {all_nan_rows_count}")
print(f"Total number of rows: {total_rows}")
print(f"Percentage of rows with NaN for every column: {all_nan_percentage:.2f}%")
# Out:
# Number of rows with NaN for every column: 1
# Total number of rows: 109045
# Percentage of rows with NaN for every column: 0.00%

# %%
# Calculate the statistics for each column in df_pivot
total_rows = len(df_pivot)
non_nan_count = df_pivot.count()
nan_count = df_pivot.isnull().sum()
nan_percentage = (nan_count / total_rows) * 100

# Store these in a DataFrame
nan_stats = pd.DataFrame({
    'ID': df_pivot.columns,
    'total_rows': total_rows,
    'non_nan_count': non_nan_count.values,
    'nan_count': nan_count.values,
    'nan_percentage': nan_percentage.values
})

print(nan_stats)

## Plot
#nan_stats.set_index('ID')['nan_percentage'].plot(kind='bar')
#plt.ylabel('Percentage of NaNs')
#plt.title('Percentage of NaNs in each column')
#plt.show()\
# Out:
#                     ID  total_rows  non_nan_count  nan_count  nan_percentage
# 0                 Date      109045         109044          1        0.000917
# 1           425_pct_Al      109045          99157       9888        9.067816
# 2              M_Value      109045          99062       9983        9.154936
# 3                Al2O3      109045          92672      16373       15.014902
# 4           C4_pct_Eth      109045          99157       9888        9.067816
# 5           C4_pct_H2O      109045          99157       9888        9.067816
# 6   HydWtr_pct_Ammonia      109045          99157       9888        9.067816
# 7           C4_pct_Hex      109045          99157       9888        9.067816
# 8          HydWtr_Na2O      109045          98559      10486        9.616213
# 9              Butanol      109045          99157       9888        9.067816
# 10             Decanol      109045          99157       9888        9.067816
# 11             DI55102      109045         108255        790        0.724472
# 12             DI55152      109045         108255        790        0.724472
# 13             DI55580      109045         108255        790        0.724472
# 14             FC55003      109045         109043          2        0.001834
# 15             FC55009      109045         109044          1        0.000917
# 16             FC55552      109045         109044          1        0.000917
# 17             FC55569      109045         109044          1        0.000917
# 18             FC55576      109045         109044          1        0.000917
# 19            FFC55553      109045         109043          2        0.001834
# 20            FFC55555      109045          99157       9888        9.067816
# 21             LC55557      109045         109043          2        0.001834
# 22             LC90366      109045          99153       9892        9.071484
# 23             LC90368      109045          99153       9892        9.071484
# 24             PI55020      109045          99157       9888        9.067816
# 25             TC55552      109045         109044          1        0.000917
# 26             TI55021      109045         109044          1        0.000917

# %%
# Create a binary matrix to represent NaNs (1 for NaN, 0 for a number)
nan_matrix = np.where(df_pivot.isna(), 1, 0)

fig, ax = plt.subplots(figsize=(15, 10))  # Adjust the size as needed
cmap = plt.get_cmap('viridis', 2)  # We use a colormap that differentiates between 0 and 1 clearly

# Plotting heatmap
cax = ax.imshow(nan_matrix, cmap=cmap, aspect='auto')

# Adding colorbar for reference
plt.colorbar(cax, ticks=[0, 1], label='NaN Presence')
plt.title("NaN Presence in Data (1 for NaN, 0 for Not NaN)", pad=20)

# To make the columns readable and vertical
plt.xticks(range(df_pivot.shape[1]), df_pivot.columns, rotation=90)  # rotation set to 90 for vertical labels

plt.xlabel('Columns')
plt.ylabel('Row Index')

plt.tight_layout()
plt.show()

# %%
# Define a threshold for the percentage of NaN values
threshold = 40

# Drop columns with more than 'threshold' percentage of NaN values
nan_stats_filtered = nan_stats[nan_stats['nan_percentage'] <= threshold]

# Get the list of columns to keep
columns_to_keep = nan_stats_filtered['ID'].tolist()


df_pivot_50pct_nan_drop = df_pivot.drop(columns=columns_to_keep)


# Filter your original DataFrame (df_pivot) to keep only the selected columns
df_pivot = df_pivot[columns_to_keep]

# Now, df_pivot_filtered contains only columns with less than or equal to 50% NaN values.

# %% [markdown]
# ### Dropped
# Because there wasn't enough viable data to process
#
# Consider revisting source data, if final model inadequate

# %%
# Describe rationale in report WHY WASN'T FURTHER ANALYSIS CONDUCTED?
df_pivot_50pct_nan_drop.columns
# Out:
# Index([], dtype='object', name='ID')

# %%
# Columns to drop for df_toomanyNaN
#columns_toomanyNaN = ['HS52551', 'XV90911']
# 'TI55565A',

# Columns to drop from df_pivot
#columns_drop_pivot = ['DI52018', 'FC52018', 'FI55580', 'LC52572', 'TC52015', 'TC55566']

# 1. Create df_toomanyNaN with the specified columns
#df_toomanyNaN = df_pivot[columns_toomanyNaN].copy()

# 2. Create df_suspect which is df_pivot minus the problematic columns
#df_suspect = df_pivot.drop(columns=columns_toomanyNaN).copy()

# 3. Drop the columns from df_pivot
#df_pivot = df_pivot.drop(columns=columns_toomanyNaN)
# + columns_drop_pivot

# %%
# Create a binary matrix to represent NaNs (1 for NaN, 0 for a number)
nan_matrix = np.where(df_pivot.isna(), 1, 0)

fig, ax = plt.subplots(figsize=(15, 10))  # Adjust the size as needed
cmap = plt.get_cmap('viridis', 2)  # We use a colormap that differentiates between 0 and 1 clearly

# Plotting heatmap
cax = ax.imshow(nan_matrix, cmap=cmap, aspect='auto')

# Adding colorbar for reference
plt.colorbar(cax, ticks=[0, 1], label='NaN Presence')
plt.title("NaN Presence in Data (1 for NaN, 0 for Not NaN)", pad=20)

# To make the columns readable and vertical
plt.xticks(range(df_pivot.shape[1]), df_pivot.columns, rotation=90)  # rotation set to 90 for vertical labels

plt.xlabel('Columns')
plt.ylabel('Row Index')

plt.tight_layout()
plt.show()

# %%
# Calculate the statistics for each column in df_pivot
total_rows = len(df_pivot)
non_nan_count = df_pivot.count()
nan_count = df_pivot.isnull().sum()
nan_percentage = (nan_count / total_rows) * 100

# Store these in a DataFrame
nan_stats = pd.DataFrame({
    'ID': df_pivot.columns,
    'total_rows': total_rows,
    'non_nan_count': non_nan_count.values,
    'nan_count': nan_count.values,
    'nan_percentage': nan_percentage.values
})

print(nan_stats)
# Out:
#                     ID  total_rows  non_nan_count  nan_count  nan_percentage
# 0                 Date      109045         109044          1        0.000917
# 1           425_pct_Al      109045          99157       9888        9.067816
# 2              M_Value      109045          99062       9983        9.154936
# 3                Al2O3      109045          92672      16373       15.014902
# 4           C4_pct_Eth      109045          99157       9888        9.067816
# 5           C4_pct_H2O      109045          99157       9888        9.067816
# 6   HydWtr_pct_Ammonia      109045          99157       9888        9.067816
# 7           C4_pct_Hex      109045          99157       9888        9.067816
# 8          HydWtr_Na2O      109045          98559      10486        9.616213
# 9              Butanol      109045          99157       9888        9.067816
# 10             Decanol      109045          99157       9888        9.067816
# 11             DI55102      109045         108255        790        0.724472
# 12             DI55152      109045         108255        790        0.724472
# 13             DI55580      109045         108255        790        0.724472
# 14             FC55003      109045         109043          2        0.001834
# 15             FC55009      109045         109044          1        0.000917
# 16             FC55552      109045         109044          1        0.000917
# 17             FC55569      109045         109044          1        0.000917
# 18             FC55576      109045         109044          1        0.000917
# 19            FFC55553      109045         109043          2        0.001834
# 20            FFC55555      109045          99157       9888        9.067816
# 21             LC55557      109045         109043          2        0.001834
# 22             LC90366      109045          99153       9892        9.071484
# 23             LC90368      109045          99153       9892        9.071484
# 24             PI55020      109045          99157       9888        9.067816
# 25             TC55552      109045         109044          1        0.000917
# 26             TI55021      109045         109044          1        0.000917

# %%
#Analysis of remaining NaNs suggests minimal impact - REMOVE

df_CD = df_pivot.dropna().copy()

# Calculate the statistics for each column in df_pivot
total_rows = len(df_CD)
non_nan_count = df_CD.count()
nan_count = df_CD.isnull().sum()
nan_percentage = (nan_count / total_rows) * 100

# Store these in a DataFrame
nan_stats = pd.DataFrame({
    'ID': df_CD.columns,
    'total_rows': total_rows,
    'non_nan_count': non_nan_count.values,
    'nan_count': nan_count.values,
    'nan_percentage': nan_percentage.values
})

print(nan_stats)
# Out:
#                     ID  total_rows  non_nan_count  nan_count  nan_percentage
# 0                 Date       92553          92553          0             0.0
# 1           425_pct_Al       92553          92553          0             0.0
# 2              M_Value       92553          92553          0             0.0
# 3                Al2O3       92553          92553          0             0.0
# 4           C4_pct_Eth       92553          92553          0             0.0
# 5           C4_pct_H2O       92553          92553          0             0.0
# 6   HydWtr_pct_Ammonia       92553          92553          0             0.0
# 7           C4_pct_Hex       92553          92553          0             0.0
# 8          HydWtr_Na2O       92553          92553          0             0.0
# 9              Butanol       92553          92553          0             0.0
# 10             Decanol       92553          92553          0             0.0
# 11             DI55102       92553          92553          0             0.0
# 12             DI55152       92553          92553          0             0.0
# 13             DI55580       92553          92553          0             0.0
# 14             FC55003       92553          92553          0             0.0
# 15             FC55009       92553          92553          0             0.0
# 16             FC55552       92553          92553          0             0.0
# 17             FC55569       92553          92553          0             0.0
# 18             FC55576       92553          92553          0             0.0
# 19            FFC55553       92553          92553          0             0.0
# 20            FFC55555       92553          92553          0             0.0
# 21             LC55557       92553          92553          0             0.0
# 22             LC90366       92553          92553          0             0.0
# 23             LC90368       92553          92553          0             0.0
# 24             PI55020       92553          92553          0             0.0
# 25             TC55552       92553          92553          0             0.0
# 26             TI55021       92553          92553          0             0.0

# %%
# 92515 Records - All duplicates removed - All NaNs removed

# %%
print(df_CD)
# Out:
# ID                    Date  425_pct_Al  M_Value    Al2O3  C4_pct_Eth  \
# 9888   2012-05-09 00:00:00     6.25494  3.56775  12.1435     2.00615
# 9889   2012-05-09 01:00:00     6.25488  3.56755  12.1315     2.00886
# 9890   2012-05-09 02:00:00     6.25482  3.56735  12.1194     2.01158
# 9891   2012-05-09 03:00:00     6.25475  3.56714  12.1074     2.01429
# 9892   2012-05-09 04:00:00     6.25469  3.56694  12.0954     2.01701
# ...                    ...         ...      ...      ...         ...
# 102555 2022-12-04 13:00:00     6.11541  3.50510  10.6407     1.48121
# 102556 2022-12-04 14:00:00     6.11547  3.50880  10.6440     1.48194
# 102557 2022-12-04 15:00:00     6.11554  3.51251  10.6472     1.48267
# 102558 2022-12-04 16:00:00     6.11561  3.51621  10.6504     1.48340
# 102559 2022-12-04 17:00:00     6.11567  3.51992  10.6536     1.48413
#
# ID      C4_pct_H2O  HydWtr_pct_Ammonia  C4_pct_Hex  HydWtr_Na2O    Butanol  \
# 9888       20.9878            0.792942    0.534483     0.306490  262.42200
# 9889       20.9930            0.786108    0.535158     0.314533  293.79000
# 9890       20.9983            0.779273    0.535832     0.322576  325.15700
# 9891       21.0036            0.772439    0.536507     0.330619  356.52400
# 9892       21.0088            0.765605    0.537181     0.338663  387.89200
# ...            ...                 ...         ...          ...        ...
# 102555     17.3827            0.971833    0.456813     0.211187    1.41333
# 102556     17.4000            0.973437    0.455406     0.210625    1.45167
# 102557     17.4173            0.975042    0.454000     0.210063    1.49000
# 102558     17.4346            0.976646    0.452594     0.209502    1.47500
# 102559     17.4519            0.978250    0.451188     0.208940    1.46000
#
# ID      Decanol   DI55102   DI55152   DI55580  FC55003   FC55009  FC55552  \
# 9888    2.93816  0.835875  0.878343  0.871840  2062.63   473.326      0.0
# 9889    3.06814  0.839648  0.889714  0.888308  1368.94   470.862      0.0
# 9890    3.19813  0.843329  0.902743  0.893221  1331.72   472.844      0.0
# 9891    3.32812  0.847874  0.912235  0.895370  1207.58   473.652      0.0
# 9892    3.45810  0.851734  0.922498  0.901391  1532.06   473.571      0.0
# ...         ...       ...       ...       ...      ...       ...      ...
# 102555  1.36333  0.794860  1.037480  1.006740  6199.13  1596.910  34090.3
# 102556  1.40667  0.794859  1.036440  1.006360  6196.80  1251.620  34047.2
# 102557  1.45000  0.794859  1.035870  1.005620  6197.68  1817.340  33949.8
# 102558  1.38833  0.794857  1.036350  1.005710  6169.00  1441.810  33993.1
# 102559  1.32667  0.794860  1.035140  1.004330  6000.13  1519.570  35074.3
#
# ID        FC55569    FC55576    FFC55553  FFC55555  LC55557  LC90366  LC90368  \
# 9888       0.0000    5.92711  178.274000  0.000000  62.7268  82.6734  61.0601
# 9889      56.9177    7.77309  149.658000  0.000000  63.9179  82.6734  62.7411
# 9890       0.0000    7.77309  155.107000  0.000000  65.4691  82.6734  64.4163
# 9891       0.0000    8.02150  139.420000  0.000000  66.3275  82.6535  66.0822
# 9892       0.0000    8.48610  150.964000  0.000000  66.4921  82.6535  67.7570
# ...           ...        ...         ...       ...      ...      ...      ...
# 102555  6767.4400  150.60300    0.977713  0.766806  66.8449  39.3429  39.6403
# 102556  6780.0200  150.45300    0.979433  0.767943  66.7806  39.3103  39.6475
# 102557  6776.1200  152.00400    0.979292  0.768010  66.8416  39.2833  39.6342
# 102558  6770.7300  149.88000    0.980534  0.770919  67.0483  39.3060  39.5829
# 102559  6773.8400  150.45900    0.974490  0.755651  66.8091  39.3738  39.5013
#
# ID       PI55020   TC55552  TI55021
# 9888   -3.849210   98.6875  186.558
# 9889   -6.054160   98.6875  175.977
# 9890   -6.469670   98.7342  173.039
# 9891   -6.406560   98.6875  172.404
# 9892   -6.115610   98.6875  156.034
# ...          ...       ...      ...
# 102555 -0.108534  152.2540  220.383
# 102556 -0.523584  152.4630  220.282
# 102557 -0.463021  152.8890  220.167
# 102558 -0.387693  152.8930  220.414
# 102559 -0.477298  153.0270  220.658
#
# [92553 rows x 27 columns]

# %%
print(df_CD.head())

# https://raw.githubusercontent.com/saust1/Project-OptiC4/main/1%20Preprocess/Continuous%20Data/contData_all.csv

# Save DataFrame to CSV file in the same directory as the Jupyter Notebook
# df_CD.to_csv(r'C:\Users\steve\OneDrive\1. BAIUTEK\Project-OptiC4\1 Preprocess\Continuous Data\contData_all.csv', index=False)

# Board workstation local copy
df_CD.to_csv(r'C:\Users\austinsh\Project-OptiC4\IV Optimize\Testing Data\Continuous Data\contData_all.csv', index=False)
# Out:
# ID                  Date  425_pct_Al  M_Value    Al2O3  C4_pct_Eth  \
# 9888 2012-05-09 00:00:00     6.25494  3.56775  12.1435     2.00615
# 9889 2012-05-09 01:00:00     6.25488  3.56755  12.1315     2.00886
# 9890 2012-05-09 02:00:00     6.25482  3.56735  12.1194     2.01158
# 9891 2012-05-09 03:00:00     6.25475  3.56714  12.1074     2.01429
# 9892 2012-05-09 04:00:00     6.25469  3.56694  12.0954     2.01701
#
# ID    C4_pct_H2O  HydWtr_pct_Ammonia  C4_pct_Hex  HydWtr_Na2O  Butanol  \
# 9888     20.9878            0.792942    0.534483     0.306490  262.422
# 9889     20.9930            0.786108    0.535158     0.314533  293.790
# 9890     20.9983            0.779273    0.535832     0.322576  325.157
# 9891     21.0036            0.772439    0.536507     0.330619  356.524
# 9892     21.0088            0.765605    0.537181     0.338663  387.892
#
# ID    Decanol   DI55102   DI55152   DI55580  FC55003  FC55009  FC55552  \
# 9888  2.93816  0.835875  0.878343  0.871840  2062.63  473.326      0.0
# 9889  3.06814  0.839648  0.889714  0.888308  1368.94  470.862      0.0
# 9890  3.19813  0.843329  0.902743  0.893221  1331.72  472.844      0.0
# 9891  3.32812  0.847874  0.912235  0.895370  1207.58  473.652      0.0
# 9892  3.45810  0.851734  0.922498  0.901391  1532.06  473.571      0.0
#
# ID    FC55569  FC55576  FFC55553  FFC55555  LC55557  LC90366  LC90368  \
# 9888   0.0000  5.92711   178.274       0.0  62.7268  82.6734  61.0601
# 9889  56.9177  7.77309   149.658       0.0  63.9179  82.6734  62.7411
# 9890   0.0000  7.77309   155.107       0.0  65.4691  82.6734  64.4163
# 9891   0.0000  8.02150   139.420       0.0  66.3275  82.6535  66.0822
# 9892   0.0000  8.48610   150.964       0.0  66.4921  82.6535  67.7570
#
# ID    PI55020  TC55552  TI55021
# 9888 -3.84921  98.6875  186.558
# 9889 -6.05416  98.6875  175.977
# 9890 -6.46967  98.7342  173.039
# 9891 -6.40656  98.6875  172.404
# 9892 -6.11561  98.6875  156.034

# %%
df_CD.describe()
# Out:
# ID                              Date    425_pct_Al       M_Value  \
# count                          92553  92553.000000  92553.000000
# mean   2017-08-21 20:20:32.945447424      2.168938      3.635282
# min              2012-05-09 00:00:00  -9986.000000      0.000000
# 25%              2014-12-29 05:00:00      5.971590      3.514180
# 50%              2017-08-23 10:00:00      6.117330      3.605230
# 75%              2020-04-13 16:00:00      6.271130      3.707800
# max              2022-12-04 17:00:00      8.058320     30.115400
# std                              NaN    160.877145      0.635045
#
# ID            Al2O3    C4_pct_Eth    C4_pct_H2O  HydWtr_pct_Ammonia  \
# count  92553.000000  92553.000000  92553.000000        92553.000000
# mean      11.164550      1.546447     20.763191            0.969719
# min        8.710000      0.001000      0.057000            0.070270
# 25%       10.701900      0.658347     18.112000            0.860995
# 50%       11.383000      1.218730     20.330700            0.933997
# 75%       11.646600      1.662020     22.904000            1.032350
# max       12.907000     90.136000     95.818000           10.726700
# std        0.713902      3.800926      4.418050            0.216378
#
# ID       C4_pct_Hex   HydWtr_Na2O       Butanol       Decanol       DI55102  \
# count  92553.000000  92553.000000  92553.000000  92553.000000  92553.000000
# mean       0.520784      0.886083    176.011148      8.837092      0.932567
# min        0.000000     -0.256120      0.000000      0.000000      0.000000
# 25%        0.321900      0.394739      4.251670      1.624940      0.891705
# 50%        0.413875      0.618339      8.253610      2.888330      0.944288
# 75%        0.522256      0.984517     36.351800      4.611670      0.985113
# max       15.840400    279.492000  36301.200000   4928.100000      1.212410
# std        0.813848      3.245811    818.676444     62.950972      0.071209
#
# ID          DI55152       DI55580       FC55003       FC55009       FC55552  \
# count  92553.000000  92553.000000  92553.000000  92553.000000  92553.000000
# mean       0.940903      0.989906   4484.205778    636.699348  26365.296809
# min        0.000000      0.000000    -24.455300    -19.480800 -12997.800000
# 25%        0.914676      0.962803   2307.640000      3.085210   3357.580000
# 50%        0.940683      0.992920   5560.140000    553.166000  35487.400000
# 75%        0.972669      1.024080   6312.810000   1125.350000  38314.600000
# max        1.317230      1.165180  20772.500000   2886.320000  52000.000000
# std        0.056787      0.057589   2701.445752    639.873636  16022.022632
#
# ID          FC55569       FC55576      FFC55553      FFC55555       LC55557  \
# count  92553.000000  92553.000000  92553.000000  92553.000000  92553.000000
# mean    5106.760993    300.330995      9.065706      1.903659     54.072011
# min        0.000000     -9.608200      0.000000      0.000000     -0.627794
# 25%     5485.360000      0.000000      0.949901      0.710053     63.726700
# 50%     6435.670000    279.601000      0.989741      0.761588     69.037000
# 75%     6734.080000    474.900000      1.020650      0.782075     71.170800
# max    12933.400000   1517.970000   2955.150000   1224.330000    100.000000
# std     2719.385231    292.335192     62.683601     28.392372     29.061892
#
# ID          LC90366       LC90368       PI55020       TC55552       TI55021
# count  92553.000000  92553.000000  92553.000000  92553.000000  92553.000000
# mean      46.273757     39.571711     -1.115853    139.100677    209.390221
# min        0.000000      0.000000     -9.653360      0.000000      0.000000
# 25%       25.193200     21.391700     -2.078970    140.063000    216.747000
# 50%       48.925700     45.396700     -0.803196    164.057000    220.642000
# 75%       67.930400     55.643500      0.000000    178.446000    225.102000
# max       87.901600     83.400400      8.981880    211.725000    741.350000
# std       26.709814     21.585760      1.250537     61.080029     46.965935

# %%
# # Ensure 'Date' is in datetime format
# df_CD['Date'] = pd.to_datetime(df_CD['Date'])

# # Calculate the difference between current and previous date-time
# df_CD['Time_Diff'] = df_CD['Date'].diff()

# # Find where 'Time_Diff' is greater than 1 hour
# gaps_over_one_hour = df_CD[df_CD['Time_Diff'] > pd.Timedelta(hours=1)]

# gaps_over_one_hour

# %%
num_columns = df_CD.shape[1]
print("Number of features:", num_columns)
# Out:
# Number of features: 27

# %% [markdown]
# After all Duplicates, NaNs, and inadequate record quantaties removed
#
# 57 Features remain
#
# Outliers are to be addressed next

# %%
from datetime import datetime

# Get the current date and time
current_date_time = datetime.now()

# Print the current date and time
print(current_date_time)
# Out:
# 2024-05-07 00:00:07.562891
