# %%
import pandas as pd
# Set max columns to display
pd.set_option('display.max_columns', None)
import numpy as np
from sklearn import preprocessing as pre
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing CSV files

# %%
########################################################################################################################
##############################                                                            ##############################
##############################                           IMPORT DATA                      ##############################      
##############################                                                            ##############################
########################################################################################################################
ABB1 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB1.csv")
ABB1_1 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB1_1.csv")
ABB1_2 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB1_2.csv")
ABB1_4 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB1_4.csv")
ABB1_6 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB1_6.csv")
ABB2 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB2.csv")
ABB2_1 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB2_1.csv")
ABB2_2 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB2_2.csv")
ABB2_4 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB2_4.csv")
ABB2_5 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB2_5.csv")
ABB3 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB3.csv")
ABB3_1 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB3_1.csv")
ABB3_2 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB3_2.csv")
ABB4 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB4.csv")
ABB51 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB51.csv")
ABB55 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB55.csv")
ABBp = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABBp.csv")

AlFlow1 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\AlFlow1.csv")

DeltaV = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\DeltaV.csv")
DeltaV1 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\DeltaV1.csv")
DeltaV2 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\DeltaV2.csv")
DeltaV4 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\DeltaV4.csv")
DeltaV5 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\DeltaV5.csv")

DeltaVp = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\DeltaVp.csv")
DeltaVR = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\DeltaVR.csv")

FC55555_ABB = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\FC55555_ABB.csv")
FC55555_DeltaV = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\FC55555_DeltaV.csv")

LIMS = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\LIM - 554 - Interpolated.csv")

rC4f_DeltaV = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\rC4f_DeltaV.csv")

# ABB1_3, #ABB1_5, #ABB5, #ABB11, ABB2_3 ,#ABB22, ABB33, ABB44, ABB56,  rC4f_ABB, LIMS1
# ABB1_3 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB1_3.csv")
# ABB1_5 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB1_5.csv")
# ABB2_3 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB2_3.csv")
# ABB5 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB5.csv")
# ABB11 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB11.csv")
# ABB22 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB22.csv")
# ABB33 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB33.csv")
# ABB44 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB44.csv")
# ABB56 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\ABB56.csv")
# DeltaV3 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\DeltaV - XV90911 - HS52551.csv")
# LIMS1 = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\LIMS1.csv")
# rC4f_ABB = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\CSVs\rC4f_ABB.csv")

# %%
# Assuming your dataframes are stored in a list like this:
dataframes = [ABB1, ABB1_1, ABB1_2, ABB1_4, ABB1_6, ABB2, ABB2_1,
                ABB2_4, ABB2_5, ABB3, ABB3_1, ABB3_2, ABB4, ABB51,
                ABB55, ABBp, AlFlow1, DeltaV, DeltaV1, DeltaV2, DeltaV4, 
                DeltaV5, DeltaVp, DeltaVR, LIMS, rC4f_DeltaV, ABB2_2
                ]

duplicates = []

# Compare each dataframe with every other dataframe
for i, df1 in enumerate(dataframes):
    for j, df2 in enumerate(dataframes):
        if i != j and df1.equals(df2):
            duplicates.append((i, j))

# Report the results
if duplicates:
    print("Duplicate dataframes found:")
    for i, j in duplicates:
        print(f"Dataframe at index {i} is the same as dataframe at index {j}.")
else:
    print("No duplicate dataframes found.")
# Out:
# No duplicate dataframes found.

# %%
# Concatenate (union) the dataframes
df = pd.concat([ABB1, ABB1_1, ABB1_2, ABB1_4, ABB1_6, 
                ABB2, ABB2_1, ABB2_2, ABB2_4, ABB2_5,
                ABB3, ABB3_1, ABB3_2, ABB4, 
                ABB51, ABB55, 
                ABBp, AlFlow1, 
                DeltaV, DeltaV1, DeltaV2, DeltaV4, DeltaV5, DeltaVp, DeltaVR,
                LIMS, 
                rC4f_DeltaV], ignore_index=True)

print(df.head())
# Out:
#             Date       ID    Value
# 0  5/9/2012 0:00  TI40050  71.6833
# 1  5/9/2012 1:00  TI40050  71.5945
# 2  5/9/2012 2:00  TI40050  71.6942
# 3  5/9/2012 3:00  TI40050  71.9178
# 4  5/9/2012 4:00  TI40050  71.7137

# %% [markdown]
# Turning off this Filter to build a complete dataset

# %%
# ids_to_drop = [

# #     # Potential Filtering or Blocking data
#         # Atomizer Data
#    "FC52018", "TI52014", "VI52558B", "II52554", 'DI52018',
#         # Stripper pressures
#    "PI55560", "PI55004", "PI55020", "TI40050", 
#         # Categorical valve postions
#    "HS90911", "HS52551", 'XV90911',
    
#     # Not Targeting with the Model
#    "AS74550-4EthanolPP", "AS74550-4HexanolPP", "AS74550-4OctanolPP"
# ]

# # Drop rows with specified IDs
# df = df[~df['ID'].isin(ids_to_drop)]

# # df.columns

# %%
print(df.shape[0])
# Out:
# 10557447

# %% [markdown]
# ## Date Filters

# %% [markdown]
# ### Filtering by a specific date:

# %%
# filtered_data = data[data['date_column_name'] < 'YYYY-MM-DD'

# %% [markdown]
# ### Filtering data after a specific date:

# %%
# Convert the date column to datetime format (if it isn't already)
# data['date_column_name'] = pd.to_datetime(data['date_column_name'])

# %% [markdown]
# ### Filtering data before a specific date:

# %%
# df = df[df['Date'] < '2020-06-15']

# %% [markdown]
# ### Filtering data between two specific dates:

# %%
# start_date = 'YYYY-MM-DD'
# end_date = 'YYYY-MM-DD'
# filtered_data = data[(data['date_column_name'] >= start_date) & (data['date_column_name'] <= end_date)]

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y %H:%M', errors='coerce')

print(df.head())
# Out:
#                  Date       ID    Value
# 0 2012-05-09 00:00:00  TI40050  71.6833
# 1 2012-05-09 01:00:00  TI40050  71.5945
# 2 2012-05-09 02:00:00  TI40050  71.6942
# 3 2012-05-09 03:00:00  TI40050  71.9178
# 4 2012-05-09 04:00:00  TI40050  71.7137

# %%
#Analysis of the larger yeallow area found an error in the timestamp conversiona
## Some timestamps were converted to "35" minutes instead of "25" minutes

#This will be corrected (yyyy-mm-dd hh:35:ss --> yyyy-mm-dd hh:00:ss)
# Assuming you have reset the index and kept the timestamp as a separate column named "Date"
#df['Date'] = df['Date'].apply(lambda dt: dt.replace(minute=0, second=0))

# Count rows where minute or second is not 0 before transformation
corrections_before = df[df['Date'].apply(lambda dt: dt.minute != 0 or dt.second != 0)].shape[0]

# Apply transformation
df['Date'] = df['Date'].apply(lambda dt: dt.replace(minute=0, second=0))

# The number of corrections is the count of rows where minute or second was not 0
print(f"{corrections_before} corrections were made.")
# Out:
# 200208 corrections were made.

# %%
#200208 - before duplicate dfs removed

# The data needs to be pivoted to:

# Unique row headers by 'Date'
# Unique column headers by 'ID'
# Values by 'Data'

#Previous attempt to pivot indicated Duplicates realtive to Date/ID
## These duplicates prevented the pivot

#First we must remove the duplicates then Pivot

# %%
#Identify the duplicates by all columns (Exact duplicates)

duplicate_counts = df.groupby(['Date', 'ID', 'Value']).size().reset_index(name='count')
duplicates_with_counts = duplicate_counts[duplicate_counts['count'] > 1]
print(duplicates_with_counts)

#165 10/24/23
#1378574 ALL DATA  ['Date', 'ID']
#1322098 ALL DATA  ['Date', 'ID', 'Data']
# Out:
#                        Date        ID         Value  count
# 141694  2011-11-06 01:00:00   FC55576      1.828960      2
# 257098  2012-05-09 00:00:00   FC55003   2062.630000      3
# 257099  2012-05-09 00:00:00   FC55009    473.326000      4
# 257100  2012-05-09 00:00:00   FC55102   2073.460000      3
# 257101  2012-05-09 00:00:00   FC55152   -864.702000      4
# ...                     ...       ...           ...    ...
# 5568805 2023-08-31 22:00:00   FC55569   6226.910000      2
# 5568806 2023-08-31 22:00:00   FC55576    484.534000      2
# 5568808 2023-08-31 22:00:00  FFC55555      0.779807      2
# 5568809 2023-08-31 22:00:00  FYC55553  30291.300000      2
# 5568822 2023-08-31 22:00:00   TC55552    159.604000      2
#
# [2796018 rows x 4 columns]

# %%
df_clean = df.drop_duplicates(subset=['Date', 'ID', 'Value'])

# %%
########## Actual Duplicates to CSV file ##########

# # Find and print duplicates based on 'Date' and 'ID' columns
# duplicates = df[df.duplicated(subset=['Date', 'ID'], keep=False)]
# print(duplicates)

# duplicates.to_csv('duplicates.csv', index=False)

# %%
# Remove the Duplicates

#Analysis of duplicates based on ID and Date are not standard across Data for all 332 occurence
# Averaging would not be consitent across all duplicate because of the wide spread between various duplicate
#Therefore REMOVE all 332 as invalid instead of introducing bias arbitraiarly 

# Drop duplicates based on 'Date' and 'ID' columns from df_clean
print(df_clean.shape[0])
# Out:
# 5663027

# %%
#Identify the duplicates

duplicate_counts = df_clean.groupby(['Date', 'ID']).size().reset_index(name='count')
duplicates_with_counts = duplicate_counts[duplicate_counts['count'] > 1]
print(duplicates_with_counts)
# Out:
#                        Date        ID  count
# 141674  2011-11-06 01:00:00  AYC55580      2
# 141675  2011-11-06 01:00:00   DI55102      2
# 141676  2011-11-06 01:00:00   DI55152      2
# 141677  2011-11-06 01:00:00   DI55580      2
# 141678  2011-11-06 01:00:00   FC55003      2
# ...                     ...       ...    ...
# 5205249 2023-07-30 22:00:00   LC52572      2
# 5205259 2023-07-30 22:00:00   TC52015      2
# 5205289 2023-07-30 23:00:00   FC52018      2
# 5205304 2023-07-30 23:00:00   LC52572      2
# 5205314 2023-07-30 23:00:00   TC52015      2
#
# [329608 rows x 3 columns]

# %%
# Assuming df_clean is your dataframe
df_clean = df_clean.drop_duplicates(subset=['Date', 'ID'], keep='first')

# %%
print(df_clean.shape[0])
# Out:
# 5239756

# %%
#Pivot the data
df_pivot = df_clean.pivot(index='Date', columns='ID', values='Value')

# Reset the index and keep the timestamp as a separate column named "Date"
df_pivot = df_pivot.reset_index()

df_pivot.head()
# Out:
# ID                Date  AS73425-3%Al  AS74550-4ButanolPP  AS74550-4DecanolPP  \
# 0                  NaT           NaN                 NaN                 NaN
# 1  2011-03-24 00:00:00           NaN                 NaN                 NaN
# 2  2011-03-24 01:00:00           NaN                 NaN                 NaN
# 3  2011-03-24 02:00:00           NaN                 NaN                 NaN
# 4  2011-03-24 03:00:00           NaN                 NaN                 NaN
#
# ID  AS74550-4EthanolPP  AS74550-4HexanolPP  AS74550-4OctanolPP  AYC55580  \
# 0                  NaN                 NaN                 NaN       NaN
# 1                  NaN                 NaN                 NaN   1.80349
# 2                  NaN                 NaN                 NaN   1.84621
# 3                  NaN                 NaN                 NaN   2.80405
# 4                  NaN                 NaN                 NaN   3.35586
#
# ID  DI52018  DI55102   DI55152   DI55580  FC03043213  FC42428  FC42428_ABB  \
# 0       NaN      NaN       NaN       NaN         NaN      NaN      18249.1
# 1       NaN  1.02539  0.942829  0.858988         NaN      NaN          NaN
# 2       NaN  1.02493  0.942729  0.859091         NaN      NaN          NaN
# 3       NaN  1.02639  0.942813  0.859834         NaN      NaN          NaN
# 4       NaN  1.02764  0.942813  0.864065         NaN      NaN          NaN
#
# ID  FC52018  FC55003  FC55009       FC55102  FC55152  FC55552  FC55555  \
# 0       NaN      NaN      NaN           NaN      NaN      NaN -70.2375
# 1       NaN      0.0  453.643  8.660000e-10 -875.000      0.0      NaN
# 2       NaN      0.0  449.570  2.070000e-08 -875.000      0.0      NaN
# 3       NaN      0.0  448.227  1.000000e-14 -873.400      0.0      NaN
# 4       NaN      0.0  449.831  5.656280e-03 -855.095      0.0      NaN
#
# ID  FC55569  FC55576  FFC55553  FFC55555  FI55580  FYC55553  HS52551  II52554  \
# 0       NaN      NaN       NaN       NaN      NaN       NaN      NaN      NaN
# 1       0.0      0.0   22.5687       NaN      NaN   451.201      NaN      NaN
# 2       0.0      0.0   22.4626       NaN      NaN   450.466      NaN      NaN
# 3       0.0      0.0   22.4968       NaN      NaN   450.532      NaN      NaN
# 4       0.0      0.0   22.3868       NaN      NaN   447.889      NaN      NaN
#
# ID  LC52572  LC55553  LC55555  LC55557   LC55568  LC90366  LC90368  PI55004  \
# 0       NaN      NaN      NaN      NaN       NaN      NaN      NaN      NaN
# 1       NaN      0.0      0.0      0.0 -0.548902      NaN      NaN      NaN
# 2       NaN      0.0      0.0      0.0 -0.562500      NaN      NaN      NaN
# 3       NaN      0.0      0.0      0.0 -0.562500      NaN      NaN      NaN
# 4       NaN      0.0      0.0      0.0 -0.562500      NaN      NaN      NaN
#
# ID  PI55020  PI55560  TC52015  TC55552  TC55553  TC55555  TC55566  TI40050  \
# 0       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1       NaN      NaN      NaN  98.6649  98.7422  98.6875      NaN      NaN
# 2       NaN      NaN      NaN  98.6875  98.7422  98.7225      NaN      NaN
# 3       NaN      NaN      NaN  98.6723  98.7422  98.7500      NaN      NaN
# 4       NaN      NaN      NaN  98.6875  98.7422  98.6875      NaN      NaN
#
# ID  TI52014  TI55013  TI55014  TI55015  TI55016  TI55017  TI55021  TI55023  \
# 0       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1       NaN  143.090  142.726  141.583  141.206  140.479  71.1300      NaN
# 2       NaN  144.502  144.267  143.485  143.292  142.366  70.5527      NaN
# 3       NaN  144.375  144.818  143.703  143.857  141.686  70.0957      NaN
# 4       NaN  142.677  142.450  145.050  145.468  148.870  69.9630      NaN
#
# ID  TI55565A  VI52558B  XV90911
# 0        NaN       NaN      NaN
# 1        NaN       NaN      NaN
# 2        NaN       NaN      NaN
# 3        NaN       NaN      NaN
# 4        NaN       NaN      NaN

# %%
num_columns = df_pivot.shape[1]
print("Number of features:", num_columns)
# Out:
# Number of features: 57

# %%
# Sample DataFrame

# Rename the columns
column_rename_dict = {
    'AS73425-3%Al': '425 %Al',
    'AS74550-4ButanolPP' : 'Butanol',
    'AS74550-4DecanolPP': 'Decanol',
    'AS74550-4EthanolPP': 'Ethanol',
    'AS74550-4HexanolPP': 'Hexanol',
    'AS74550-4OctanolPP': 'Octanol'


}

df_pivot = df_pivot.rename(columns=column_rename_dict)

df_pivot
# Out:
# ID                    Date  425 %Al  Butanol  Decanol  Ethanol  Hexanol  \
# 0                      NaT      NaN      NaN      NaN      NaN      NaN
# 1      2011-03-24 00:00:00      NaN      NaN      NaN      NaN      NaN
# 2      2011-03-24 01:00:00      NaN      NaN      NaN      NaN      NaN
# 3      2011-03-24 02:00:00      NaN      NaN      NaN      NaN      NaN
# 4      2011-03-24 03:00:00      NaN      NaN      NaN      NaN      NaN
# ...                    ...      ...      ...      ...      ...      ...
# 109040 2023-08-31 19:00:00  6.32960  2.54333  3.30667  3.69333  2.07667
# 109041 2023-08-31 20:00:00  6.32490  2.58667  3.54333  3.88167  2.13333
# 109042 2023-08-31 21:00:00  6.32021  2.63000  3.78000  4.07000  2.19000
# 109043 2023-08-31 22:00:00  6.31551  2.63500  3.85667  4.08000  2.20833
# 109044 2023-08-31 23:00:00  6.31082  2.64000  3.93333  4.09000  2.22667
#
# ID      Octanol  AYC55580  DI52018  DI55102   DI55152   DI55580  FC03043213  \
# 0           NaN       NaN      NaN      NaN       NaN       NaN         NaN
# 1           NaN   1.80349      NaN  1.02539  0.942829  0.858988         NaN
# 2           NaN   1.84621      NaN  1.02493  0.942729  0.859091         NaN
# 3           NaN   2.80405      NaN  1.02639  0.942813  0.859834         NaN
# 4           NaN   3.35586      NaN  1.02764  0.942813  0.864065         NaN
# ...         ...       ...      ...      ...       ...       ...         ...
# 109040  2.84333       NaN      NaN      NaN       NaN       NaN         NaN
# 109041  2.97167       NaN      NaN      NaN       NaN       NaN         NaN
# 109042  3.10000       NaN      NaN      NaN       NaN       NaN         NaN
# 109043  3.14500       NaN      NaN      NaN       NaN       NaN         NaN
# 109044  3.19000       NaN      NaN      NaN       NaN       NaN         NaN
#
# ID      FC42428  FC42428_ABB  FC52018  FC55003  FC55009       FC55102  \
# 0           NaN      18249.1      NaN      NaN      NaN           NaN
# 1           NaN          NaN      NaN     0.00  453.643  8.660000e-10
# 2           NaN          NaN      NaN     0.00  449.570  2.070000e-08
# 3           NaN          NaN      NaN     0.00  448.227  1.000000e-14
# 4           NaN          NaN      NaN     0.00  449.831  5.656280e-03
NaN       NaN       NaN       NaN      NaN      NaN      NaN
# 1           NaN   98.6649   98.7422   98.6875      NaN      NaN      NaN
# 2           NaN   98.6875   98.7422   98.7225      NaN      NaN      NaN
# 3           NaN   98.6723   98.7422   98.7500      NaN      NaN      NaN
# 4           NaN   98.6875   98.7422   98.6875      NaN      NaN      NaN
# ...         ...       ...       ...       ...      ...      ...      ...
# 109040  99.9242  159.7830  193.6240  180.0190  199.770  96.4326      NaN
# 109041  96.3565  159.7250  191.8990  179.8170  200.164  94.5965      NaN
# 109042  93.6134  159.4370  192.4350  179.9180  200.028  91.9880      NaN
# 109043  91.0423  159.6040  194.3870  179.8670  199.995  90.0690      NaN
# 109044      NaN  159.5480       NaN       NaN      NaN      NaN      NaN
#
# ID      TI55013  TI55014  TI55015  TI55016  TI55017   TI55021  TI55023  \
# 0           NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 1       143.090  142.726  141.583  141.206  140.479   71.1300      NaN
# 2       144.502  144.267  143.485  143.292  142.366   70.5527      NaN
# 3       144.375  144.818  143.703  143.857  141.686   70.0957      NaN
# 4       142.677  142.450  145.050  145.468  148.870   69.9630      NaN
# ...         ...      ...      ...      ...      ...       ...      ...
# 109040  209.217      NaN      NaN      NaN  186.304  225.5510  225.215
# 109041  209.571      NaN      NaN      NaN  186.954  225.8760  224.725
# 109042  209.099      NaN      NaN      NaN  186.513  225.4130  224.349
# 109043  209.383      NaN      NaN      NaN  186.783  225.3410  224.598
# 109044  208.422      NaN      NaN      NaN  185.932  225.4400  224.481
#
# ID      TI55565A  VI52558B  XV90911
# 0            NaN       NaN      NaN
# 1            NaN       NaN      NaN
# 2            NaN       NaN      NaN
# 3            NaN       NaN      NaN
# 4            NaN       NaN      NaN
# ...          ...       ...      ...
# 109040       NaN       NaN      0.0
# 109041       NaN       NaN      0.0
# 109042       NaN       NaN      0.0
# 109043       NaN       NaN      0.0
# 109044       NaN       NaN      NaN
#
# [109045 rows x 57 columns]

# %%
df_pivot.columns
# Out:
# Index(['Date', '425 %Al', 'Butanol', 'Decanol', 'Ethanol', 'Hexanol',
#        'Octanol', 'AYC55580', 'DI52018', 'DI55102', 'DI55152', 'DI55580',
#        'FC03043213', 'FC42428', 'FC42428_ABB', 'FC52018', 'FC55003', 'FC55009',
#        'FC55102', 'FC55152', 'FC55552', 'FC55555', 'FC55569', 'FC55576',
#        'FFC55553', 'FFC55555', 'FI55580', 'FYC55553', 'HS52551', 'II52554',
#        'LC52572', 'LC55553', 'LC55555', 'LC55557', 'LC55568', 'LC90366',
#        'LC90368', 'PI55004', 'PI55020', 'PI55560', 'TC52015', 'TC55552',
#        'TC55553', 'TC55555', 'TC55566', 'TI40050', 'TI52014', 'TI55013',
#        'TI55014', 'TI55015', 'TI55016', 'TI55017', 'TI55021', 'TI55023',
#        'TI55565A', 'VI52558B', 'XV90911'],
#       dtype='object', name='ID')

# %%
# To Address the NaNs .....................................................

# %%
# Count NaNs in each row
nan_counts_per_row = df_pivot.isnull().sum(axis=1)

# Frequency distribution of NaN counts
frequency_distribution = nan_counts_per_row.value_counts().sort_index()

print(frequency_distribution)
# Out:
# 1     12406
# 3      7671
# 4      7044
# 6       911
# 7     70319
# 8        14
# 11      764
# 13        1
# 14        3
# 16       23
# 30     9887
# 34        1
# 55        1
# dtype: int64

# %%
# Count of rows where all values are NaN
all_nan_rows_count = df_pivot.isnull().all(axis=1).sum()

# Total number of rows in pivoted_df
total_rows = len(df_pivot)

# Percentage of rows that are completely NaN
all_nan_percentage = (all_nan_rows_count / total_rows) * 100

print(f"Number of rows with NaN for every column: {all_nan_rows_count}")
print(f"Total number of rows: {total_rows}")
print(f"Percentage of rows with NaN for every column: {all_nan_percentage:.2f}%")
# Out:
# Number of rows with NaN for every column: 0
# Total number of rows: 109045
# Percentage of rows with NaN for every column: 0.00%

# %%
# Calculate the statistics for each column in df_pivot
total_rows = len(df_pivot)
non_nan_count = df_pivot.count()
nan_count = df_pivot.isnull().sum()
nan_percentage = (nan_count / total_rows) * 100

# Store these in a DataFrame
nan_stats = pd.DataFrame({
    'ID': df_pivot.columns,
    'total_rows': total_rows,
    'non_nan_count': non_nan_count.values,
    'nan_count': nan_count.values,
    'nan_percentage': nan_percentage.values
})

print(nan_stats)

## Plot
#nan_stats.set_index('ID')['nan_percentage'].plot(kind='bar')
#plt.ylabel('Percentage of NaNs')
#plt.title('Percentage of NaNs in each column')
#plt.show()\
# Out:
#              ID  total_rows  non_nan_count  nan_count  nan_percentage
# 0          Date      109045         109044          1        0.000917
# 1       425 %Al      109045          99157       9888        9.067816
# 2       Butanol      109045          99157       9888        9.067816
# 3       Decanol      109045          99157       9888        9.067816
# 4       Ethanol      109045          99157       9888        9.067816
# 5       Hexanol      109045          99157       9888        9.067816
# 6       Octanol      109045          99157       9888        9.067816
# 7      AYC55580      109045         108255        790        0.724472
# 8       DI52018      109045          12406      96639       88.623046
# 9       DI55102      109045         108255        790        0.724472
# 10      DI55152      109045         108255        790        0.724472
# 11      DI55580      109045         108255        790        0.724472
# 12   FC03043213      109045          28797      80248       73.591636
# 13      FC42428      109045          99132       9913        9.090742
# 14  FC42428_ABB      109045              1     109044       99.999083
# 15      FC52018      109045          99139       9906        9.084323
# 16      FC55003      109045         109043          2        0.001834
# 17      FC55009      109045         109044          1        0.000917
# 18      FC55102      109045         109043          2        0.001834
# 19      FC55152      109045         109044          1        0.000917
# 20      FC55552      109045         109044          1        0.000917
# 21      FC55555      109045          99158       9887        9.066899
# 22      FC55569      109045         109044          1        0.000917
# 23      FC55576      109045         109044          1        0.000917
# 24     FFC55553      109045         109043          2        0.001834
# 25     FFC55555      109045          99157       9888        9.067816
# 26      FI55580      109045          16971      92074       84.436700
# 27     FYC55553      109045         109044          1        0.000917
# 28      HS52551      109045          16304      92741       85.048375
# 29      II52554      109045          99109       9936        9.111835
# 30      LC52572      109045          99153       9892        9.071484
# 31      LC55553      109045         109043          2        0.001834
# 32      LC55555      109045         109043          2        0.001834
# 33      LC55557      109045         109043          2        0.001834
# 34      LC55568      109045         109043          2        0.001834
# 35      LC90366      109045          99153       9892        9.071484
# 36      LC90368      109045          99153       9892        9.071484
# 37      PI55004      109045          99157       9888        9.067816
# 38      PI55020      109045          99157       9888        9.067816
# 39      PI55560      109045          99157       9888        9.067816
# 40      TC52015      109045          99153       9892        9.071484
# 41      TC55552      109045         109044          1        0.000917
# 42      TC55553      109045         109043          2        0.001834
# 43      TC55555      109045         109043          2        0.001834
# 44      TC55566      109045          99153       9892        9.071484
# 45      TI40050      109045          99153       9892        9.071484
# 46      TI52014      109045          99109       9936        9.111835
# 47      TI55013      109045         109044          1        0.000917
# 48      TI55014      109045         108255        790        0.724472
# 49      TI55015      109045         108255        790        0.724472
# 50      TI55016      109045         108255        790        0.724472
# 51      TI55017      109045         109044          1        0.000917
# 52      TI55021      109045         109044          1        0.000917
# 53      TI55023      109045          99157       9888        9.067816
# 54     TI55565A      109045          27165      81880       75.088266
# 55     VI52558B      109045          99109       9936        9.111835
# 56      XV90911      109045          27932      81113       74.384887

# %%
# Create a binary matrix to represent NaNs (1 for NaN, 0 for a number)
nan_matrix = np.where(df_pivot.isna(), 1, 0)

fig, ax = plt.subplots(figsize=(15, 10))  # Adjust the size as needed
cmap = plt.get_cmap('viridis', 2)  # We use a colormap that differentiates between 0 and 1 clearly

# Plotting heatmap
cax = ax.imshow(nan_matrix, cmap=cmap, aspect='auto')

# Adding colorbar for reference
plt.colorbar(cax, ticks=[0, 1], label='NaN Presence')
plt.title("NaN Presence in Data (1 for NaN, 0 for Not NaN)", pad=20)

# To make the columns readable and vertical
plt.xticks(range(df_pivot.shape[1]), df_pivot.columns, rotation=90)  # rotation set to 90 for vertical labels

plt.xlabel('Columns')
plt.ylabel('Row Index')

plt.tight_layout()
plt.show()

# %%
# Define a threshold for the percentage of NaN values
threshold = 50

# Drop columns with more than 'threshold' percentage of NaN values
nan_stats_filtered = nan_stats[nan_stats['nan_percentage'] <= threshold]

# Get the list of columns to keep
columns_to_keep = nan_stats_filtered['ID'].tolist()


df_pivot_50pct_nan_drop = df_pivot.drop(columns=columns_to_keep)


# Filter your original DataFrame (df_pivot) to keep only the selected columns
df_pivot = df_pivot[columns_to_keep]

# Now, df_pivot_filtered contains only columns with less than or equal to 50% NaN values.

# %% [markdown]
# ### Reportable

# %%
# Describe rationale in report WHY WASN'T FURTHER ANALYSIS CONDUCTED?
df_pivot_50pct_nan_drop.columns
# Out:
# Index(['DI52018', 'FC03043213', 'FC42428_ABB', 'FI55580', 'HS52551',
#        'TI55565A', 'XV90911'],
#       dtype='object', name='ID')

# %%
# Columns to drop for df_toomanyNaN
#columns_toomanyNaN = ['HS52551', 'XV90911']
# 'TI55565A',

# Columns to drop from df_pivot
#columns_drop_pivot = ['DI52018', 'FC52018', 'FI55580', 'LC52572', 'TC52015', 'TC55566']

# 1. Create df_toomanyNaN with the specified columns
#df_toomanyNaN = df_pivot[columns_toomanyNaN].copy()

# 2. Create df_suspect which is df_pivot minus the problematic columns
#df_suspect = df_pivot.drop(columns=columns_toomanyNaN).copy()

# 3. Drop the columns from df_pivot
#df_pivot = df_pivot.drop(columns=columns_toomanyNaN)
# + columns_drop_pivot

# %%
# Create a binary matrix to represent NaNs (1 for NaN, 0 for a number)
nan_matrix = np.where(df_pivot.isna(), 1, 0)

fig, ax = plt.subplots(figsize=(15, 10))  # Adjust the size as needed
cmap = plt.get_cmap('viridis', 2)  # We use a colormap that differentiates between 0 and 1 clearly

# Plotting heatmap
cax = ax.imshow(nan_matrix, cmap=cmap, aspect='auto')

# Adding colorbar for reference
plt.colorbar(cax, ticks=[0, 1], label='NaN Presence')
plt.title("NaN Presence in Data (1 for NaN, 0 for Not NaN)", pad=20)

# To make the columns readable and vertical
plt.xticks(range(df_pivot.shape[1]), df_pivot.columns, rotation=90)  # rotation set to 90 for vertical labels

plt.xlabel('Columns')
plt.ylabel('Row Index')

plt.tight_layout()
plt.show()

# %%
# Calculate the statistics for each column in df_pivot
total_rows = len(df_pivot)
non_nan_count = df_pivot.count()
nan_count = df_pivot.isnull().sum()
nan_percentage = (nan_count / total_rows) * 100

# Store these in a DataFrame
nan_stats = pd.DataFrame({
    'ID': df_pivot.columns,
    'total_rows': total_rows,
    'non_nan_count': non_nan_count.values,
    'nan_count': nan_count.values,
    'nan_percentage': nan_percentage.values
})

print(nan_stats)
# Out:
#           ID  total_rows  non_nan_count  nan_count  nan_percentage
# 0       Date      109045         109044          1        0.000917
# 1    425 %Al      109045          99157       9888        9.067816
# 2    Butanol      109045          99157       9888        9.067816
# 3    Decanol      109045          99157       9888        9.067816
# 4    Ethanol      109045          99157       9888        9.067816
# 5    Hexanol      109045          99157       9888        9.067816
# 6    Octanol      109045          99157       9888        9.067816
# 7   AYC55580      109045         108255        790        0.724472
# 8    DI55102      109045         108255        790        0.724472
# 9    DI55152      109045         108255        790        0.724472
# 10   DI55580      109045         108255        790        0.724472
# 11   FC42428      109045          99132       9913        9.090742
# 12   FC52018      109045          99139       9906        9.084323
# 13   FC55003      109045         109043          2        0.001834
# 14   FC55009      109045         109044          1        0.000917
# 15   FC55102      109045         109043          2        0.001834
# 16   FC55152      109045         109044          1        0.000917
# 17   FC55552      109045         109044          1        0.000917
# 18   FC55555      109045          99158       9887        9.066899
# 19   FC55569      109045         109044          1        0.000917
# 20   FC55576      109045         109044          1        0.000917
# 21  FFC55553      109045         109043          2        0.001834
# 22  FFC55555      109045          99157       9888        9.067816
# 23  FYC55553      109045         109044          1        0.000917
# 24   II52554      109045          99109       9936        9.111835
# 25   LC52572      109045          99153       9892        9.071484
# 26   LC55553      109045         109043          2        0.001834
# 27   LC55555      109045         109043          2        0.001834
# 28   LC55557      109045         109043          2        0.001834
# 29   LC55568      109045         109043          2        0.001834
# 30   LC90366      109045          99153       9892        9.071484
# 31   LC90368      109045          99153       9892        9.071484
# 32   PI55004      109045          99157       9888        9.067816
# 33   PI55020      109045          99157       9888        9.067816
# 34   PI55560      109045          99157       9888        9.067816
# 35   TC52015      109045          99153       9892        9.071484
# 36   TC55552      109045         109044          1        0.000917
# 37   TC55553      109045         109043          2        0.001834
# 38   TC55555      109045         109043          2        0.001834
# 39   TC55566      109045          99153       9892        9.071484
# 40   TI40050      109045          99153       9892        9.071484
# 41   TI52014      109045          99109       9936        9.111835
# 42   TI55013      109045         109044          1        0.000917
# 43   TI55014      109045         108255        790        0.724472
# 44   TI55015      109045         108255        790        0.724472
# 45   TI55016      109045         108255        790        0.724472
# 46   TI55017      109045         109044          1        0.000917
# 47   TI55021      109045         109044          1        0.000917
# 48   TI55023      109045          99157       9888        9.067816
# 49  VI52558B      109045          99109       9936        9.111835

# %%
#Analysis of remaining NaNs suggests minimal impact - REMOVE

df_CD = df_pivot.dropna().copy()

# Calculate the statistics for each column in df_pivot
total_rows = len(df_CD)
non_nan_count = df_CD.count()
nan_count = df_CD.isnull().sum()
nan_percentage = (nan_count / total_rows) * 100

# Store these in a DataFrame
nan_stats = pd.DataFrame({
    'ID': df_CD.columns,
    'total_rows': total_rows,
    'non_nan_count': non_nan_count.values,
    'nan_count': nan_count.values,
    'nan_percentage': nan_percentage.values
})

print(nan_stats)
# Out:
#           ID  total_rows  non_nan_count  nan_count  nan_percentage
# 
\
# count  98327.000000  98327.000000  98327.000000  98327.000000  98327.000000
# mean       8.565719      1.839758  26602.011980    143.331518     57.830755
# std       60.808648     27.547306  15406.575187     69.210373     16.216936
# min        0.000000      0.000000    -29.830200   -192.500000     -5.000000
# 25%        0.946653      0.720765  17879.850000    132.095000     60.569250
# 50%        0.988701      0.768304  34845.100000    158.997000     62.875000
# 75%        1.020060      0.787371  38032.900000    184.493000     64.802400
# max     2955.150000   1224.330000  62468.000000    288.395000    102.781000
#
# ID          LC55553       LC55555       LC55557       LC55568       LC90366  \
# count  98327.000000  98327.000000  98327.000000  98327.000000  98327.000000
# mean      49.993496     46.691614     55.215005     32.773431     46.849329
# std       26.673514     25.840620     28.555279     17.459507     26.170208
# min       -0.631361     -0.631604     -0.627794     -0.750000      0.000000
# 25%       49.090500     42.436150     64.262500     36.846000     27.162150
# 50%       64.350500     55.301100     69.328300     40.790400     49.762300
# 75%       67.400800     65.154700     71.452900     41.429250     67.214850
# max      104.850000    104.971000    100.000000    104.992000     87.901600
#
# ID          LC90368       PI55004       PI55020       PI55560       TC52015  \
# count  98327.000000  98327.000000  98327.000000  98327.000000  98327.000000
# mean      40.422922      1.776657     -1.096718      0.803513     74.688712
# std       21.400513      1.757398      1.230524      1.287644     16.822128
# min        0.000000     -9.935260     -9.653360     -4.811260      0.000000
# 25%       23.206350      0.501265     -2.028380      0.000000     63.954100
# 50%       46.332100      1.593240     -0.793228      0.471566     75.886100
# 75%       56.268200      2.824055     -0.003117      1.538110     84.677150
# max       83.400400     21.190600      8.981880     11.053200    204.872000
#
# ID          TC55552       TC55553       TC55555       TC55566       TI40050  \
# count  98327.000000  98327.000000  98327.000000  98327.000000  98327.000000
# mean     140.739104    149.818781    150.774947    161.262216    195.154524
# std       59.686011     69.047767     63.253902     74.415205    316.477217
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      142.188000    135.086000    179.601000    174.002000     67.019900
# 50%      164.559000    167.764000    180.043000    194.758000     79.615600
# 75%      178.445500    191.974000    181.860500    204.682000     89.667200
# max      213.521000    280.195000    297.875000    321.837000   1022.350000
#
# ID          TI52014       TI55013       TI55014       TI55015       TI55016  \
# count  98327.000000  98327.000000  98327.000000  98327.000000  98327.000000
# mean     140.369322    186.951318    186.239821    181.337855    180.824158
# std       95.715374     42.640330     34.936177     39.238189     30.716239
# min      -44.760100      0.000000      0.000000      0.000000      0.000000
# 25%      117.675000    181.286000    181.802000    179.430000    180.514500
# 50%      128.844000    197.006000    194.197000    191.513000    188.244000
# 75%      138.107000    210.720500    204.364000    202.057500    195.343000
# max      930.853000    250.439000    234.651000    233.318000    225.277000
#
# ID          TI55017       TI55021       TI55023      VI52558B
# count  98327.000000  98327.000000  98327.000000  98327.000000
# mean     174.611802    209.794279    204.989796      2.498648
# std       38.643645     46.396290     48.224073      1.468497
# min        0.000000      0.000000      0.000000     -6.038090
# 25%      175.811000    216.933500    215.045500      1.829735
# 50%      183.399000    220.968000    218.073000      2.442150
# 75%      191.675000    225.424500    221.979000      3.152640
# max      648.368000    741.350000    695.788000     40.676500

# %%
# # Ensure 'Date' is in datetime format
# df_CD['Date'] = pd.to_datetime(df_CD['Date'])

# # Calculate the difference between current and previous date-time
# df_CD['Time_Diff'] = df_CD['Date'].diff()

# # Find where 'Time_Diff' is greater than 1 hour
# gaps_over_one_hour = df_CD[df_CD['Time_Diff'] > pd.Timedelta(hours=1)]

# gaps_over_one_hour

# %%
num_columns = df_CD.shape[1]
print("Number of features:", num_columns)
# Out:
# Number of features: 50
