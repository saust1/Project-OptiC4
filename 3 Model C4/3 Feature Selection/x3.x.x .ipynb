# %%
import pandas as pd
# Set max columns to display
pd.set_option('display.max_columns', None)

import numpy as np
from sklearn import preprocessing as pre
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import plotly.express as px

import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px
import numpy as np

# %%
# df_CDCO = pd.read_csv(r"C:\Users\saust\OneDrive - Sasol\1 Project rC4\Jupyter Notebooks\Report 10-19-23\df_AlConCD554.csv")
df_CDCO = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\CodeSpace DLs\102423\Project RC4\3 Final Machine Butanol\df_CDFSI.csv")

# df_CDCO = pd.read_csv('/workspaces/codespaces-jupyter/ProjectrC4/df_AlConCD554.csv')

# %% [markdown]
# # Check Basic Information:

# %%
df_CDCO.info() #to check the data types, non-null counts, and memory usage.
df_CDCO.head() #to examine the first few rows of the dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50586 entries, 0 to 50585
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   425 %Al   50586 non-null  float64
#  1   FC55569   50586 non-null  float64
#  2   TC55552   50586 non-null  float64
#  3   FC55576   50586 non-null  float64
#  4   TI55017   50586 non-null  float64
#  5   FYC55553  50586 non-null  float64
#  6   FFC55555  50586 non-null  float64
#  7   FC55009   50586 non-null  float64
#  8   FC42428   50586 non-null  float64
#  9   TI55013   50586 non-null  float64
#  10  TI55023   50586 non-null  float64
#  11  TI55021   50586 non-null  float64
#  12  FC55152   50586 non-null  float64
#  13  FC55552   50586 non-null  float64
#  14  Date      50586 non-null  object
#  15  Butanol   50586 non-null  float64
# dtypes: float64(15), object(1)
# memory usage: 6.2+ MB
#    425 %Al  FC55569  TC55552  FC55576  TI55017  FYC55553  FFC55555  FC55009  \
# ...

# %% [markdown]
# # Summary Statistics:

# %%
df_CDCO.describe() #to get summary statistics for numeric columns.
# Out:
#             425 %Al       FC55569       TC55552       FC55576       TI55017  \
# count  50586.000000  50586.000000  50586.000000  50586.000000  50586.000000
# mean       6.126383   6578.409316    168.500125    396.888685    186.414527
# std        0.277131    370.158649     15.062009    251.789034      9.718733
# min        4.788500   5167.950000    120.264000      0.000548    159.702000
# 25%        5.988960   6338.290000    156.412000    233.360750    179.070250
# 50%        6.127550   6554.525000    171.749000    357.573500    185.647000
# 75%        6.274605   6782.230000    180.167500    576.458000    192.242750
# max        7.435470   8016.850000    207.426000   1129.050000    212.051000
#
#            FYC55553      FFC55555       FC55009       FC42428       TI55013  \
# count  50586.000000  50586.000000  5.058600e+04  50586.000000  50586.000000
# mean   35650.848820      0.772067  8.671014e+02  35990.752293    201.545702
# ...

# %%
# Initialize the Dash app
app = dash.Dash(__name__)

app.layout = html.Div([
    dcc.Graph(id='scatter-plot'),
    dcc.RangeSlider(
        id='range-slider',
        min=df_CDCO['Butanol'].min(),
        max=df_CDCO['Butanol'].max(),
        value=[20, 80],
        marks={str(val): str(val) for val in df_CDCO['Butanol'].unique()}
    )
])

@app.callback(
    Output('feature-plot', 'figure'),
    [Input('target-range-slider', 'value'),
     Input('feature-dropdown', 'value')]
)
def update_figure(selected_range, selected_feature):
    mask = (df_CDCO['Butanol'] >= selected_range[0]) & (df_CDCO['Butanol'] <= selected_range[1])
    filtered_df = df_CDCO[mask]
    fig = px.scatter(filtered_df, x='Butanol', y=selected_feature)
    return fig

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
