# %%
import pandas as pd
# Set max columns to display
pd.set_option('display.max_columns', None)
import numpy as np
from sklearn import preprocessing as pre
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing CSV files

# %%
########################################################################################################################
##############################                                                            ##############################
##############################                           IMPORT DATA                      ##############################      
##############################                                                            ##############################
########################################################################################################################
ABB1_split_1 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB1_split_1.csv")
ABB1_split_2 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB1_split_2.csv")
ABB1_1 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB1_1.csv")
ABB1_2 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB1_2.csv")
ABB1_4 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB1_4.csv")
ABB1_6 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB1_6.csv")
ABB2_split_1 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB2_split_1.csv")
ABB2_split_2 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB2_split_2.csv")
ABB2_1 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB2_1.csv")
ABB2_2 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB2_2.csv")
ABB2_4 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB2_4.csv")
ABB2_5 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB2_5.csv")
ABB3 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB3.csv")
ABB3_1 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB3_1.csv")
ABB3_2 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB3_2.csv")
ABB4 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB4.csv")
ABB51 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB51.csv")
ABB55 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB55.csv")
ABBp = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABBp.csv")

AlFlow1 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\AlFlow1.csv")

DeltaV = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\DeltaV.csv")
DeltaV1 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\DeltaV1.csv")
DeltaV2 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\DeltaV2.csv")
DeltaV4 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\DeltaV4.csv")
DeltaV5 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\DeltaV5.csv")

DeltaVp = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\DeltaVp.csv")

DeltaVR_split_1 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\DeltaVR_split_1.csv")
DeltaVR_split_2 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\DeltaVR_split_2.csv")


FC55555_ABB = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\FC55555_ABB.csv")
FC55555_DeltaV = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\FC55555_DeltaV.csv")

LIMS = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\LIM - 554 - Interpolated.csv")
LIMS1 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\LIMS Actuals\LIMS1.csv")
LIMS2 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\LIMS Actuals\LIMS2.csv")
LIMS3 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\LIMS Actuals\LIMS3.csv")
LIMS4 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\LIMS Actuals\LIMS4.csv")


rC4f_DeltaV = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\rC4f_DeltaV.csv")

# ABB1_3, #ABB1_5, #ABB5, #ABB11, ABB2_3 ,#ABB22, ABB33, ABB44, ABB56,  rC4f_ABB, LIMS1
# ABB1_3 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB1_3.csv")
# ABB1_5 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB1_5.csv")
# ABB2_3 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB2_3.csv")
# ABB5 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB5.csv")
# ABB11 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB11.csv")
# ABB22 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB22.csv")
# ABB33 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB33.csv")
# ABB44 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB44.csv")
# ABB56 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\ABB56.csv")
# DeltaV3 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\DeltaV - XV90911 - HS52551.csv")
# LIMS1 = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\LIMS1.csv")
# rC4f_ABB = pd.read_csv(r"C:\Users\saust\OneDrive\Desktop\GitRepo\Project-OptiC4\CSV\PVs\rC4f_ABB.csv")

# %%
# Assuming your dataframes are stored in a list like this:
dataframes = [ABB1_split_1, ABB1_split_2, ABB1_1, ABB1_2, ABB1_4, ABB1_6, ABB2_split_1, ABB2_split_2, ABB2_1,
                ABB2_4, ABB2_5, ABB3, ABB3_1, ABB3_2, ABB4, ABB51,
                ABB55, ABBp, AlFlow1, DeltaV, DeltaV1, DeltaV2, DeltaV4, 
                DeltaV5, DeltaVp, DeltaVR_split_1, DeltaVR_split_2, LIMS, rC4f_DeltaV, ABB2_2
                ]

duplicates = []

# Compare each dataframe with every other dataframe
for i, df1 in enumerate(dataframes):
    for j, df2 in enumerate(dataframes):
        if i != j and df1.equals(df2):
            duplicates.append((i, j))

# Report the results
if duplicates:
    print("Duplicate dataframes found:")
    for i, j in duplicates:
        print(f"Dataframe at index {i} is the same as dataframe at index {j}.")
else:
    print("No duplicate dataframes found.")
# Out:
# No duplicate dataframes found.

# %%
# Concatenate (union) the dataframes
df = pd.concat([ABB1_split_1, ABB1_split_2, ABB1_1, ABB1_2, ABB1_4, ABB1_6, 
                ABB2_split_1, ABB2_split_2, ABB2_1, ABB2_2, ABB2_4, ABB2_5,
                ABB3, ABB3_1, ABB3_2, ABB4, 
                ABB51, ABB55, 
                ABBp, AlFlow1, 
                DeltaV, DeltaV1, DeltaV2, DeltaV4, DeltaV5, DeltaVp, DeltaVR_split_1, DeltaVR_split_2,
                LIMS, LIMS1, LIMS2, LIMS3, LIMS4,
                rC4f_DeltaV], ignore_index=True)

print(df.head())
# Out:
#             Date       ID    Value
# 0  5/9/2012 0:00  TI40050  71.6833
# 1  5/9/2012 1:00  TI40050  71.5945
# 2  5/9/2012 2:00  TI40050  71.6942
# 3  5/9/2012 3:00  TI40050  71.9178
# 4  5/9/2012 4:00  TI40050  71.7137

# %% [markdown]
# Turning off this Filter to build a complete dataset

# %%
# Assuming df is your DataFrame and 'ID' is the column
distinct_ids = df['ID'].unique()

print("Distinct IDs:")
print(distinct_ids)
# Out:
# Distinct IDs:
# ['TI40050' 'FC52018' 'FC55003' 'FC55009' 'FC55102' 'FC55152' 'FC55552'
#  'FC55569' 'FC55576' 'FFC55553' 'FFC55555' 'FYC55553' 'LC52572' 'LC55553'
#  'LC55555' 'LC55557' 'LC55568' 'LC90366' 'LC90368' 'TC52015' 'TC55552'
#  'TC55553' 'TC55555' 'TC55566' 'TI55017' 'TI55013' 'TI55021' 'TI55023'
#  'PI55004' 'PI55560' 'PI55020' 'AYC55580' 'DI55102' 'TI55014' 'TI55015'
#  'TI55016' 'DI55152' 'DI55580' 'FC55555' 'TI52014' 'II52554' 'VI52558B'
#  'FC42428' 'FC42428_ABB' 'FC03043213' 'HS52551' 'XV90911' 'DI52018'
#  'FI55580' 'TI55565A' 'AS74550-4EthanolPP' 'AS74550-4ButanolPP'
#  'AS74550-4HexanolPP' 'AS74550-4OctanolPP' 'AS74550-4DecanolPP'
#  'AS73425-3%Al' 'AS74550-25%C2OH' 'AS74550-25%nC6OH' 'AS74550-25%nC4OH'
#  'AS74550-25%H2O' 'AS74550-10%M-Value' 'AS74550-1%Al2O3' 'AS74550-5%pH'
#  'AS74550-5ppmNa2O' 'AS74550-5%NH4OH']

# %%
ids_to_keep = ['AS73425-3%Al', 'AS74550-4ButanolPP',
                    'FC55569', 'DI55152', 'TC55552',
                    'FC55003', 'LC55555', 'FFC55553',
                    'FFC55555', 'TC55555', 'TI55021',
                    'PI55004', 'FC55552',
                                 
               'AS74550-25%C2OH', 'AS74550-25%nC6OH', 'AS74550-25%nC4OH',
               'AS74550-25%H2O', 'AS74550-10%M-Value', 
               'AS74550-5%pH', 'AS74550-5ppmNa2O', 'AS74550-5%NH4OH'
               ]


   # 'AS74550-4DecanolPP': 'Decanol',


# Keep only rows with specified IDs
df = df[df['ID'].isin(ids_to_keep)]

# %%
print(df.shape[0])
# Out:
# 4038417

# %% [markdown]
# ## Date Filters

# %% [markdown]
# ### Filtering by a specific date:

# %%
# filtered_data = data[data['date_column_name'] < 'YYYY-MM-DD'

# %% [markdown]
# ### Filtering data after a specific date:

# %%
# Convert the date column to datetime format (if it isn't already)
# data['date_column_name'] = pd.to_datetime(data['date_column_name'])

# %% [markdown]
# ### Filtering data before a specific date:

# %%
# df = df[df['Date'] < '2020-06-15']

# %% [markdown]
# ### Filtering data between two specific dates:

# %%
# start_date = 'YYYY-MM-DD'
# end_date = 'YYYY-MM-DD'
# filtered_data = data[(data['date_column_name'] >= start_date) & (data['date_column_name'] <= end_date)]

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y %H:%M', errors='coerce')

print(df.head())
# Out:
#                      Date       ID    Value
# 76894 2012-05-09 00:00:00  FC55003  2062.63
# 76895 2012-05-09 01:00:00  FC55003  1368.94
# 76896 2012-05-09 02:00:00  FC55003  1331.72
# 76897 2012-05-09 03:00:00  FC55003  1207.58
# 76898 2012-05-09 04:00:00  FC55003  1532.06

# %%
#Analysis of the larger yeallow area found an error in the timestamp conversiona
## Some timestamps were converted to "35" minutes instead of "25" minutes

#This will be corrected (yyyy-mm-dd hh:35:ss --> yyyy-mm-dd hh:00:ss)
# Assuming you have reset the index and kept the timestamp as a separate column named "Date"
#df['Date'] = df['Date'].apply(lambda dt: dt.replace(minute=0, second=0))

# Count rows where minute or second is not 0 before transformation
corrections_before = df[df['Date'].apply(lambda dt: dt.minute != 0 or dt.second != 0)].shape[0]

# Apply transformation
df['Date'] = df['Date'].apply(lambda dt: dt.replace(minute=0, second=0))

# The number of corrections is the count of rows where minute or second was not 0
print(f"{corrections_before} corrections were made.")
# Out:
# 0 corrections were made.

# %%
#200208 - before duplicate dfs removed

# The data needs to be pivoted to:

# Unique row headers by 'Date'
# Unique column headers by 'ID'
# Values by 'Data'

#Previous attempt to pivot indicated Duplicates realtive to Date/ID
## These duplicates prevented the pivot

#First we must remove the duplicates then Pivot

# %%
#Identify the duplicates by all columns (Exact duplicates)

duplicate_counts = df.groupby(['Date', 'ID', 'Value']).size().reset_index(name='count')
duplicates_with_counts = duplicate_counts[duplicate_counts['count'] > 1]
print(duplicates_with_counts)

#165 10/24/23
#1378574 ALL DATA  ['Date', 'ID']
#1322098 ALL DATA  ['Date', 'ID', 'Data']
# Out:
#                        Date        ID         Value  count
# 89003   2012-05-09 00:00:00   FC55003   2062.630000      3
# 89004   2012-05-09 00:00:00   FC55552      0.000000      4
# 89005   2012-05-09 00:00:00   FC55569      0.000000      4
# 89006   2012-05-09 00:00:00  FFC55553    178.274000      3
# 89007   2012-05-09 00:00:00  FFC55555      0.000000      3
# ...                     ...       ...           ...    ...
# 2168763 2023-08-31 21:00:00   TC55552    159.437000      2
# 2168775 2023-08-31 22:00:00   FC55552  34045.100000      2
# 2168776 2023-08-31 22:00:00   FC55569   6226.910000      2
# 2168778 2023-08-31 22:00:00  FFC55555      0.779807      2
# 2168781 2023-08-31 22:00:00   TC55552    159.604000      2
#
# [959760 rows x 4 columns]

# %%
df_clean = df.drop_duplicates(subset=['Date', 'ID', 'Value'])

# %%
########## Actual Duplicates to CSV file ##########

# # Find and print duplicates based on 'Date' and 'ID' columns
# duplicates = df[df.duplicated(subset=['Date', 'ID'], keep=False)]
# print(duplicates)

# duplicates.to_csv('duplicates.csv', index=False)

# %%
# Remove the Duplicates

#Analysis of duplicates based on ID and Date are not standard across Data for all 332 occurence
# Averaging would not be consitent across all duplicate because of the wide spread between various duplicate
#Therefore REMOVE all 332 as invalid instead of introducing bias arbitraiarly 

# Drop duplicates based on 'Date' and 'ID' columns from df_clean
print(df_clean.shape[0])
# Out:
# 2169662

# %%
#Identify the duplicates

duplicate_counts = df_clean.groupby(['Date', 'ID']).size().reset_index(name='count')
duplicates_with_counts = duplicate_counts[duplicate_counts['count'] > 1]
print(duplicates_with_counts)
# Out:
#                        Date        ID  count
# 49041   2011-11-06 01:00:00   DI55152      2
# 49042   2011-11-06 01:00:00   FC55003      2
# 49043   2011-11-06 01:00:00   FC55552      2
# 49044   2011-11-06 01:00:00   FC55569      2
# 49045   2011-11-06 01:00:00  FFC55553      2
# ...                     ...       ...    ...
# 1905444 2022-11-06 01:00:00   PI55004      2
# 1905445 2022-11-06 01:00:00   TC55552      2
# 1905446 2022-11-06 01:00:00   TC55555      2
# 1905447 2022-11-06 01:00:00   TI55021      2
# 1909030 2022-11-13 22:00:00   FC55552      2
#
# [128685 rows x 3 columns]

# %%
# Assuming df_clean is your dataframe
df_clean = df_clean.drop_duplicates(subset=['Date', 'ID'], keep='first')

# %%
print(df_clean.shape[0])
# Out:
# 2040963

# %%
#Pivot the data
df_pivot = df_clean.pivot(index='Date', columns='ID', values='Value')

# Reset the index and keep the timestamp as a separate column named "Date"
df_pivot = df_pivot.reset_index()

df_pivot.head()
# Out:
# ID                Date  AS73425-3%Al  AS74550-10%M-Value  AS74550-25%C2OH  \
# 0  2011-03-24 00:00:00           NaN                 NaN              NaN
# 1  2011-03-24 01:00:00           NaN                 NaN              NaN
# 2  2011-03-24 02:00:00           NaN                 NaN              NaN
# 3  2011-03-24 03:00:00           NaN                 NaN              NaN
# 4  2011-03-24 04:00:00           NaN                 NaN              NaN
#
# ID  AS74550-25%H2O  AS74550-25%nC4OH  AS74550-25%nC6OH  AS74550-4ButanolPP  \
# 0              NaN               NaN               NaN                 NaN
# 1              NaN               NaN               NaN                 NaN
# 2              NaN               NaN               NaN                 NaN
# 3              NaN               NaN               NaN                 NaN
# 4              NaN               NaN               NaN                 NaN
#
# ID  AS74550-5%NH4OH  AS74550-5%pH  AS74550-5ppmNa2O   DI55152  FC55003  \
# 0               NaN           NaN               NaN  0.942829      0.0
# 1               NaN           NaN               NaN  0.942729      0.0
# 2               NaN           NaN               NaN  0.942813      0.0
# 3               NaN           NaN               NaN  0.942813      0.0
# 4               NaN           NaN               NaN  0.942732      0.0
#
# ID  FC55552  FC55569  FFC55553  FFC55555  LC55555  PI55004  TC55552  TC55555  \
# 0       0.0      0.0   22.5687       NaN      0.0      NaN  98.6649  98.6875
# 1       0.0      0.0   22.4626       NaN      0.0      NaN  98.6875  98.7225
# 2       0.0      0.0   22.4968       NaN      0.0      NaN  98.6723  98.7500
# 3       0.0      0.0   22.3868       NaN      0.0      NaN  98.6875  98.6875
# 4       0.0      0.0   22.4329       NaN      0.0      NaN  98.6745  98.7115
#
# ID  TI55021
# 0   71.1300
# 1   70.5527
# 2   70.0957
# 3   69.9630
# 4   69.9212

# %%
num_columns = df_pivot.shape[1]
print("Number of features:", num_columns)
# Out:
# Number of features: 22

# %%
# Sample DataFrame

# Rename the columns
column_rename_dict = {
    'AS73425-3%Al': '425_pct_Al',
    'AS74550-4ButanolPP' : 'Butanol',
    'AS74550-4DecanolPP': 'Decanol',
    'AS74550-4EthanolPP': 'Ethanol',
    'AS74550-4HexanolPP': 'Hexanol',
    'AS74550-4OctanolPP': 'Octanol',
    'AS74550-25%C2OH': 'C4_pct_Eth',
    'AS74550-25%nC6OH': 'C4_pct_Hex',
    'AS74550-25%nC4OH': 'C4_pct_But',
    'AS74550-25%H2O': 'C4_pct_H2O',
    'AS74550-10%M-Value': 'M_Value',
    'AS74550-5%pH': 'HydWtr_pH',
    'AS74550-5ppmNa2O' : 'HydWtr_Na2O',
    'AS74550-5%NH4OH': 'HydWtr_pct_Ammonia'
}

df_pivot = df_pivot.rename(columns=column_rename_dict)

df_pivot
# Out:
# ID                    Date  425_pct_Al  M_Value  C4_pct_Eth  C4_pct_H2O  \
# 0      2011-03-24 00:00:00         NaN      NaN         NaN         NaN
# 1      2011-03-24 01:00:00         NaN      NaN         NaN         NaN
# 2      2011-03-24 02:00:00         NaN      NaN         NaN         NaN
# 3      2011-03-24 03:00:00         NaN      NaN         NaN         NaN
# 4      2011-03-24 04:00:00         NaN      NaN         NaN         NaN
# ...                    ...         ...      ...         ...         ...
# 109039 2023-08-31 19:00:00     6.32960  3.55641     1.73850     18.1064
# 109040 2023-08-31 20:00:00     6.32490  3.55531     1.73862     18.1091
# 109041 2023-08-31 21:00:00     6.32021  3.55420     1.73875     18.1118
# 109042 2023-08-31 22:00:00     6.31551  3.55310     1.73888     18.1145
# 109043 2023-08-31 23:00:00     6.31082  3.55200     1.73900     18.1172
#
# ID      C4_pct_But  C4_pct_Hex  Butanol  HydWtr_pct_Ammonia  HydWtr_pH  \
# 0              NaN         NaN      NaN                 NaN        NaN
# 1              NaN         NaN      NaN                 NaN        NaN
# 2              NaN         NaN      NaN                 NaN        NaN
# 3              NaN         NaN      NaN                 NaN        NaN
# 4              NaN         NaN      NaN                 NaN        NaN
# ...            ...         ...      ...                 ...        ...
# 109039         NaN    0.519485  2.54333            0.923854        NaN
# 109040         NaN    0.519932  2.58667            0.922469        NaN
# 109041         NaN    0.520379  2.63000            0.921083        NaN
# 109042         NaN    0.520826  2.63500            0.919698        NaN
# 109043         NaN    0.521273  2.64000            0.918313        NaN
#
# ID      HydWtr_Na2O   DI55152  FC55003  FC55552  FC55569   FFC55553  FFC55555  \
# 0               NaN  0.942829     0.00      0.0     0.00  22.568700       NaN
# 1               NaN  0.942729     0.00      0.0     0.00  22.462600       NaN
# 2               NaN  0.942813     0.00      0.0     0.00  22.496800       NaN
# 3               NaN  0.942813     0.00      0.0     0.00  22.386800       NaN
# 4               NaN  0.942732     0.00      0.0     0.00  22.432900       NaN
# ...             ...       ...      ...      ...      ...        ...       ...
# 109039      2.20398       NaN  5048.33  33986.9  6226.74   0.888830  0.779393
# 109040      2.20735       NaN  5135.09  34018.0  6219.08   0.891949  0.781521
# 109041      2.21072       NaN  5273.17  34064.9  6171.00   0.891380  0.778299
# 109042      2.21409       NaN  5315.33  34045.1  6226.91   0.891981  0.779807
# 109043      2.21746       NaN      NaN  33948.5  6215.25        NaN  0.779985
#
# ID      LC55555  PI55004   TC55552   TC55555   TI55021
# 0        0.0000      NaN   98.6649   98.6875   71.1300
# 1        0.0000      NaN   98.6875   98.7225   70.5527
# 2        0.0000      NaN   98.6723   98.7500   70.0957
# 3        0.0000      NaN   98.6875   98.6875   69.9630
# 4        0.0000      NaN   98.6745   98.7115   69.9212
# ...         ...      ...       ...       ...       ...
# 109039  77.3944  3.60928  159.7830  180.0190  225.5510
# 109040  77.6482  3.41220  159.7250  179.8170  225.8760
# 109041  76.8171  3.31190  159.4370  179.9180  225.4130
# 109042  77.1744  3.37153  159.6040  179.8670  225.3410
# 109043      NaN  3.34497  159.5480       NaN  225.4400
#
# [109044 rows x 22 columns]

# %%
df_pivot.columns
# Out:
# Index(['Date', '425_pct_Al', 'M_Value', 'C4_pct_Eth', 'C4_pct_H2O',
#        'C4_pct_But', 'C4_pct_Hex', 'Butanol', 'HydWtr_pct_Ammonia',
#        'HydWtr_pH', 'HydWtr_Na2O', 'DI55152', 'FC55003', 'FC55552', 'FC55569',
#        'FFC55553', 'FFC55555', 'LC55555', 'PI55004', 'TC55552', 'TC55555',
#        'TI55021'],
#       dtype='object', name='ID')

# %%
# To Address the NaNs .....................................................

# %%
# Count NaNs in each row
nan_counts_per_row = df_pivot.isnull().sum(axis=1)

# Frequency distribution of NaN counts
frequency_distribution = nan_counts_per_row.value_counts().sort_index()

print(frequency_distribution)
# Out:
# 0      4884
# 1     58906
# 2     33982
# 3      1384
# 7         1
# 12     9887
# dtype: int64

# %%
# Count of rows where all values are NaN
all_nan_rows_count = df_pivot.isnull().all(axis=1).sum()

# Total number of rows in pivoted_df
total_rows = len(df_pivot)

# Percentage of rows that are completely NaN
all_nan_percentage = (all_nan_rows_count / total_rows) * 100

print(f"Number of rows with NaN for every column: {all_nan_rows_count}")
print(f"Total number of rows: {total_rows}")
print(f"Percentage of rows with NaN for every column: {all_nan_percentage:.2f}%")
# Out:
# Number of rows with NaN for every column: 0
# Total number of rows: 109044
# Percentage of rows with NaN for every column: 0.00%

# %%
# Calculate the statistics for each column in df_pivot
total_rows = len(df_pivot)
non_nan_count = df_pivot.count()
nan_count = df_pivot.isnull().sum()
nan_percentage = (nan_count / total_rows) * 100

# Store these in a DataFrame
nan_stats = pd.DataFrame({
    'ID': df_pivot.columns,
    'total_rows': total_rows,
    'non_nan_count': non_nan_count.values,
    'nan_count': nan_count.values,
    'nan_percentage': nan_percentage.values
})

print(nan_stats)

## Plot
#nan_stats.set_index('ID')['nan_percentage'].plot(kind='bar')
#plt.ylabel('Percentage of NaNs')
#plt.title('Percentage of NaNs in each column')
#plt.show()\
# Out:
#                     ID  total_rows  non_nan_count  nan_count  nan_percentage
# 0                 Date      109044         109044          0        0.000000
# 1           425_pct_Al      109044          99157       9887        9.066982
# 2              M_Value      109044          99062       9982        9.154103
# 3           C4_pct_Eth      109044          99157       9887        9.066982
# 4           C4_pct_H2O      109044          99157       9887        9.066982
# 5           C4_pct_But      109044           4884     104160       95.521074
# 6           C4_pct_Hex      109044          99157       9887        9.066982
# 7              Butanol      109044          99157       9887        9.066982
# 8   HydWtr_pct_Ammonia      109044          99157       9887        9.066982
# 9            HydWtr_pH      109044          63887      45157       41.411724
# 10         HydWtr_Na2O      109044          98559      10485        9.615385
# 11             DI55152      109044         108255        789        0.723561
# 12             FC55003      109044         109043          1        0.000917
# 13             FC55552      109044         109044          0        0.000000
# 14             FC55569      109044         109044          0        0.000000
# 15            FFC55553      109044         109043          1        0.000917
# 16            FFC55555      109044          99157       9887        9.066982
# 17             LC55555      109044         109043          1        0.000917
# 18             PI55004      109044          99157       9887        9.066982
# 19             TC55552      109044         109044          0        0.000000
# 20             TC55555      109044         109043          1        0.000917
# 21             TI55021      109044         109044          0        0.000000

# %%
# Create a binary matrix to represent NaNs (1 for NaN, 0 for a number)
nan_matrix = np.where(df_pivot.isna(), 1, 0)

fig, ax = plt.subplots(figsize=(15, 10))  # Adjust the size as needed
cmap = plt.get_cmap('viridis', 2)  # We use a colormap that differentiates between 0 and 1 clearly

# Plotting heatmap
cax = ax.imshow(nan_matrix, cmap=cmap, aspect='auto')

# Adding colorbar for reference
plt.colorbar(cax, ticks=[0, 1], label='NaN Presence')
plt.title("NaN Presence in Data (1 for NaN, 0 for Not NaN)", pad=20)

# To make the columns readable and vertical
plt.xticks(range(df_pivot.shape[1]), df_pivot.columns, rotation=90)  # rotation set to 90 for vertical labels

plt.xlabel('Columns')
plt.ylabel('Row Index')

plt.tight_layout()
plt.show()

# %%
# Define a threshold for the percentage of NaN values
threshold = 40

# Drop columns with more than 'threshold' percentage of NaN values
nan_stats_filtered = nan_stats[nan_stats['nan_percentage'] <= threshold]

# Get the list of columns to keep
columns_to_keep = nan_stats_filtered['ID'].tolist()


df_pivot_50pct_nan_drop = df_pivot.drop(columns=columns_to_keep)


# Filter your original DataFrame (df_pivot) to keep only the selected columns
df_pivot = df_pivot[columns_to_keep]

# Now, df_pivot_filtered contains only columns with less than or equal to 50% NaN values.

# %% [markdown]
# ### Reportable

# %%
# Describe rationale in report WHY WASN'T FURTHER ANALYSIS CONDUCTED?
df_pivot_50pct_nan_drop.columns
# Out:
# Index(['C4_pct_But', 'HydWtr_pH'], dtype='object', name='ID')

# %%
# Columns to drop for df_toomanyNaN
#columns_toomanyNaN = ['HS52551', 'XV90911']
# 'TI55565A',

# Columns to drop from df_pivot
#columns_drop_pivot = ['DI52018', 'FC52018', 'FI55580', 'LC52572', 'TC52015', 'TC55566']

# 1. Create df_toomanyNaN with the specified columns
#df_toomanyNaN = df_pivot[columns_toomanyNaN].copy()

# 2. Create df_suspect which is df_pivot minus the problematic columns
#df_suspect = df_pivot.drop(columns=columns_toomanyNaN).copy()

# 3. Drop the columns from df_pivot
#df_pivot = df_pivot.drop(columns=columns_toomanyNaN)
# + columns_drop_pivot

# %%
# Create a binary matrix to represent NaNs (1 for NaN, 0 for a number)
nan_matrix = np.where(df_pivot.isna(), 1, 0)

fig, ax = plt.subplots(figsize=(15, 10))  # Adjust the size as needed
cmap = plt.get_cmap('viridis', 2)  # We use a colormap that differentiates between 0 and 1 clearly

# Plotting heatmap
cax = ax.imshow(nan_matrix, cmap=cmap, aspect='auto')

# Adding colorbar for reference
plt.colorbar(cax, ticks=[0, 1], label='NaN Presence')
plt.title("NaN Presence in Data (1 for NaN, 0 for Not NaN)", pad=20)

# To make the columns readable and vertical
plt.xticks(range(df_pivot.shape[1]), df_pivot.columns, rotation=90)  # rotation set to 90 for vertical labels

plt.xlabel('Columns')
plt.ylabel('Row Index')

plt.tight_layout()
plt.show()

# %%
# Calculate the statistics for each column in df_pivot
total_rows = len(df_pivot)
non_nan_count = df_pivot.count()
nan_count = df_pivot.isnull().sum()
nan_percentage = (nan_count / total_rows) * 100

# Store these in a DataFrame
nan_stats = pd.DataFrame({
    'ID': df_pivot.columns,
    'total_rows': total_rows,
    'non_nan_count': non_nan_count.values,
    'nan_count': nan_count.values,
    'nan_percentage': nan_percentage.values
})

print(nan_stats)
# Out:
#                     ID  total_rows  non_nan_count  nan_count  nan_percentage
# 0                 Date      109044         109044          0        0.000000
# 1           425_pct_Al      109044          99157       9887        9.066982
# 2              M_Value      109044          99062       9982        9.154103
# 3           C4_pct_Eth      109044          99157       9887        9.066982
# 4           C4_pct_H2O      109044          99157       9887        9.066982
# 5           C4_pct_Hex      109044          99157       9887        9.066982
# 6              Butanol      109044          99157       9887        9.066982
# 7   HydWtr_pct_Ammonia      109044          99157       9887        9.066982
# 8          HydWtr_Na2O      109044          98559      10485        9.615385
# 9              DI55152      109044         108255        789        0.723561
# 10             FC55003      109044         109043          1        0.000917
# 11             FC55552      109044         109044          0        0.000000
# 12             FC55569      109044         109044          0        0.000000
# 13            FFC55553      109044         109043          1        0.000917
# 14            FFC55555      109044          99157       9887        9.066982
# 15             LC55555      109044         109043          1        0.000917
# 16             PI55004      109044          99157       9887        9.066982
# 17             TC55552      109044         109044          0        0.000000
# 18             TC55555      109044         109043          1        0.000917
# 19             TI55021      109044         109044          0        0.000000

# %%
#Analysis of remaining NaNs suggests minimal impact - REMOVE

df_CD = df_pivot.dropna().copy()

# Calculate the statistics for each column in df_pivot
total_rows = len(df_CD)
non_nan_count = df_CD.count()
nan_count = df_CD.isnull().sum()
nan_percentage = (nan_count / total_rows) * 100

# Store these in a DataFrame
nan_stats = pd.DataFrame({
    'ID': df_CD.columns,
    'total_rows': total_rows,
    'non_nan_count': non_nan_count.values,
    'nan_count': nan_count.values,
    'nan_percentage': nan_percentage.values
})

print(nan_stats)
# Out:
#                     ID  total_rows  non_nan_count  nan_count  nan_percentage
# 0                 Date       97675          97675          0             0.0
# 1           425_pct_Al       97675          97675          0             0.0
# 2              M_Value       97675          97675          0             0.0
# 3           C4_pct_Eth       97675          97675          0             0.0
# 4           C4_pct_H2O       97675          97675          0             0.0
# 5           C4_pct_Hex       97675          97675          0             0.0
# 6              Butanol       97675          97675          0             0.0
# 7   HydWtr_pct_Ammonia       97675          97675          0             0.0
# 8          HydWtr_Na2O       97675          97675          0             0.0
# 9              DI55152       97675          97675          0             0.0
# 10             FC55003       97675          97675          0             0.0
# 11             FC55552       97675          97675          0             0.0
# 12             FC55569       97675          97675          0             0.0
# 13            FFC55553       97675          97675          0             0.0
# 14            FFC55555       97675          97675          0             0.0
# 15             LC55555       97675          97675          0             0.0
# 16             PI55004       97675          97675          0             0.0
# 17             TC55552       97675          97675          0             0.0
# 18             TC55555       97675          97675          0             0.0
# 19             TI55021       97675          97675          0             0.0

# %%
# 97675
# 98327
# 98207
# 98367

# %%
print(df_CD)
# Out:
# ID                    Date  425_pct_Al  M_Value  C4_pct_Eth  C4_pct_H2O  \
# 9887   2012-05-09 00:00:00     6.25494  3.56775     2.00615     20.9878
# 9888   2012-05-09 01:00:00     6.25488  3.56755     2.00886     20.9930
# 9889   2012-05-09 02:00:00     6.25482  3.56735     2.01158     20.9983
# 9890   2012-05-09 03:00:00     6.25475  3.56714     2.01429     21.0036
# 9891   2012-05-09 04:00:00     6.25469  3.56694     2.01701     21.0088
# ...                    ...         ...      ...         ...         ...
# 108271 2023-07-30 19:00:00     6.42876  3.57863     2.22128     19.1822
# 108272 2023-07-30 20:00:00     6.42722  3.57548     2.22705     19.1842
# 108273 2023-07-30 21:00:00     6.42569  3.57234     2.23283     19.1861
# 108274 2023-07-30 22:00:00     6.42415  3.56919     2.23861     19.1881
# 108275 2023-07-30 23:00:00     6.42261  3.56604     2.24438     19.1900
#
# ID      C4_pct_Hex    Butanol  HydWtr_pct_Ammonia  HydWtr_Na2O   DI55152  \
# 9887      0.534483  262.42200            0.792942     0.306490  0.878343
# 9888      0.535158  293.79000            0.786108     0.314533  0.889714
# 9889      0.535832  325.15700            0.779273     0.322576  0.902743
# 9890      0.536507  356.52400            0.772439     0.330619  0.912235
# 9891      0.537181  387.89200            0.765605     0.338663  0.922498
# ...            ...        ...                 ...          ...       ...
# 108271    0.297574    1.14333            0.708823     3.639880  0.972144
# 108272    0.297982    1.08667            0.705578     3.649290  0.972438
# 108273    0.298390    1.03000            0.702333     3.658700  0.972971
# 108274    0.298798    1.03167            0.699089     3.668100  0.973530
# 108275    0.299206    1.03333            0.695844     3.677510  0.974321
#
# ID      FC55003  FC55552    FC55569    FFC55553  FFC55555  LC55555  PI55004  \
# 9887    2062.63      0.0     0.0000  178.274000  0.000000  61.3521  3.44917
# 9888    1368.94      0.0    56.9177  149.658000  0.000000  63.0291  3.33412
# 9889    1331.72      0.0     0.0000  155.107000  0.000000  64.1343  3.04671
# 9890    1207.58      0.0     0.0000  139.420000  0.000000  65.1766  2.78534
# 9891    1532.06      0.0     0.0000  150.964000  0.000000  65.6451  2.50412
# ...         ...      ...        ...         ...       ...      ...      ...
# 108271  5266.95  33006.8  6355.5500    0.987505  0.797193  76.9908  4.95210
# 108272  5624.11  33020.7  6396.2600    0.988701  0.801872  77.0267  4.89812
# 108273  5847.00  33157.3  6364.7400    0.993005  0.801522  77.0490  4.82127
# 108274  6009.97  32926.0  6432.1900    0.992214  0.802123  76.9750  4.48567
# 108275  5762.77  33022.0  6399.1200    0.987609  0.800024  76.9937  4.46081
#
# ID       TC55552  TC55555  TI55021
# 9887     98.6875  169.719  186.558
# 9888     98.6875  172.146  175.977
# 9889     98.7342  173.747  173.039
# 9890     98.6875  177.941  172.404
# 9891     98.6875  179.625  156.034
# ...          ...      ...      ...
# 108271  179.1700  180.234  230.200
# 108272  178.7860  179.994  230.783
# 108273  178.6450  180.078  230.684
# 108274  178.4490  180.067  231.012
# 108275  178.3170  179.940  229.282
#
# [97675 rows x 20 columns]

# %%
print(df_CD.head())

# Save DataFrame to CSV file in the same directory as the Jupyter Notebook
df_CD.to_csv('contData_all.csv', index=False)
# Out:
# ID                  Date  425_pct_Al  M_Value  C4_pct_Eth  C4_pct_H2O  \
# 9887 2012-05-09 00:00:00     6.25494  3.56775     2.00615     20.9878
# 9888 2012-05-09 01:00:00     6.25488  3.56755     2.00886     20.9930
# 9889 2012-05-09 02:00:00     6.25482  3.56735     2.01158     20.9983
# 9890 2012-05-09 03:00:00     6.25475  3.56714     2.01429     21.0036
# 9891 2012-05-09 04:00:00     6.25469  3.56694     2.01701     21.0088
#
# ID    C4_pct_Hex  Butanol  HydWtr_pct_Ammonia  HydWtr_Na2O   DI55152  FC55003  \
# 9887    0.534483  262.422            0.792942     0.306490  0.878343  2062.63
# 9888    0.535158  293.790            0.786108     0.314533  0.889714  1368.94
# 9889    0.535832  325.157            0.779273     0.322576  0.902743  1331.72
# 9890    0.536507  356.524            0.772439     0.330619  0.912235  1207.58
# 9891    0.537181  387.892            0.765605     0.338663  0.922498  1532.06
#
# ID    FC55552  FC55569  FFC55553  FFC55555  LC55555  PI55004  TC55552  \
# 9887      0.0   0.0000   178.274       0.0  61.3521  3.44917  98.6875
# 9888      0.0  56.9177   149.658       0.0  63.0291  3.33412  98.6875
# 9889      0.0   0.0000   155.107       0.0  64.1343  3.04671  98.7342
# 9890      0.0   0.0000   139.420       0.0  65.1766  2.78534  98.6875
# 9891      0.0   0.0000   150.964       0.0  65.6451  2.50412  98.6875
#
# ID    TC55555  TI55021
# 9887  169.719  186.558
# 9888  172.146  175.977
# 9889  173.747  173.039
# 9890  177.941  172.404
# 9891  179.625  156.034

# %%
df_CD.describe()
# Out:
# ID       425_pct_Al       M_Value    C4_pct_Eth    C4_pct_H2O    C4_pct_Hex  \
# count  97675.000000  97675.000000  97675.000000  97675.000000  97675.000000
# mean       2.372545      3.635591      1.557511     20.612519      0.514260
# std      156.604582      0.618836      3.701786      4.356163      0.793046
# min    -9986.000000      0.000000      0.001000      0.057000      0.000000
# 25%        5.973750      3.516855      0.681930     17.984800      0.323000
# 50%        6.120170      3.606910      1.265670     20.052800      0.412198
# 75%        6.268290      3.708370      1.672050     22.790850      0.517836
# max        8.058320     30.115400     90.136000     95.818000     15.840400
#
# ID          Butanol  HydWtr_pct_Ammonia   HydWtr_Na2O       DI55152  \
# count  97675.000000        97675.000000  97675.000000  97675.000000
# mean     170.329150            0.967146      0.960200      0.945141
# std      804.494946            0.218444      3.651101      0.058427
# min        0.000000            0.021000     -0.256120      0.000000
# 25%        4.063400            0.861474      0.389235      0.916205
# 50%        7.803330            0.935000      0.616935      0.943462
# 75%       34.119400            1.034035      1.002525      0.981420
# max    36301.200000           10.726700    279.492000      1.317230
#
# ID          FC55003       FC55552       FC55569      FFC55553      FFC55555  \
# count  97675.000000  97675.000000  97675.000000  97675.000000  97675.000000
# mean    4534.501879  26628.365467   5159.163768      8.642655      1.846413
# std     2662.170762  15871.658077   2677.354223     61.044423     27.638980
# min      -24.455300 -12997.800000      0.000000      0.000000      0.000000
# 25%     3298.685000  17671.600000   5702.805000      0.944019      0.720402
# 50%     5572.400000  35755.600000   6437.200000      0.988546      0.767929
# 75%     6311.105000  38113.550000   6738.185000      1.020090      0.786486
# max    20772.500000  52000.000000  12933.400000   2955.150000   1224.330000
#
# ID          LC55555       PI55004       TC55552       TC55555       TI55021
# count  97675.000000  97675.000000  97675.000000  97675.000000  97675.000000
# mean      46.492267      1.772517    140.428734    150.530347    209.687824
# std       25.834790      1.761427     59.834690     63.457087     46.547459
# min       -0.631604     -9.935260      0.000000      0.000000      0.000000
# 25%       42.196650      0.478593    141.830000    179.574000    216.913000
# 50%       55.127900      1.582950    164.366000    180.040000    220.931000
# 75%       65.108000      2.822090    178.313000    181.874000    225.418000
# max      104.971000     21.190600    213.521000    297.875000    741.350000

# %%
# # Ensure 'Date' is in datetime format
# df_CD['Date'] = pd.to_datetime(df_CD['Date'])

# # Calculate the difference between current and previous date-time
# df_CD['Time_Diff'] = df_CD['Date'].diff()

# # Find where 'Time_Diff' is greater than 1 hour
# gaps_over_one_hour = df_CD[df_CD['Time_Diff'] > pd.Timedelta(hours=1)]

# gaps_over_one_hour

# %%
num_columns = df_CD.shape[1]
print("Number of features:", num_columns)
# Out:
# Number of features: 20
